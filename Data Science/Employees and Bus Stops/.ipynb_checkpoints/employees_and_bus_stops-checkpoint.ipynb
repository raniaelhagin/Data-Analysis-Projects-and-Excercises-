# %% [markdown]
# # Employee and Bus Stops
#
# ## Context
#
# A company XYZ intends to provide a bus shuttle service that would help its employees commute to the office. The company is based in Mountain View and the shuttle would provide transportation for employees based in San Francisco.
#
# The city of San Francisco has given the company a list of potential bus stops that it may use. However, the company may use no more than 10 of these bus stops for its shuttle service.
#
# The company XYZ is asking you to come up with the **10 most efficient bus stops** that would best serve its employees. Generally speaking, these "efficient" stops would result in the least walking distances between the employees' homes and their respective bus stops. To that end, you were given the following data:
# - the list of bus stops provided by the city of San Francisco, `Bus_Stops.csv`
# - a list of its employees' home addresses, `Employee_Addresses.csv`
#
# Since trying out all possible combinations of 10 bus stops would take a prohibitively long time, the boss of XYZ has told you that you may simplify the problem and come up with 10 reasonable bus stops that are probably efficient.
#
# ## Objectives
#
# - Explore and analyze the data. Provide comments on the outputs of your code and document your code well.
# - Feel free to show off your map visualization skills.
# - Write an algorithm that produces the 10 best stops in your opinion. Also, please explain the rationale behind the algorithm.
# - Please the calculate the average walking distance per employee to their respective stops and report it at the end of your work.
# - You may code the solution for this task in either Python or R. If you are coding in Python, you may enter your solution at the bottom of this notebook. Otherwise, you may create a new R jupyter notebook and copy this problem description over there. Either way, your solution is to be in the form of a jupyter notebook, regardless of the programming language used.
# - Submit your work along with the data files used (`Bus_Stops.csv` & `Employee_Addresses.csv`) in a single ZIP file named as follows: `<FirstName>_<LastName>.zip`
#
# ## Evaluation
#
# ***Your solution will be evaluated on:***
# - ***The soundness of the algorithm used to select the bus stops.***
# - ***How much your code is neat, clear and well-documented.***
# - ***Quality of narrative and commentary with interesting analyses and visuals.***
#
# ## Supplementary Notes
#
# Prior to writing the requested algorithm, you will need to *geocode* the employees' home addresses and bus stops. You may use the [HERE REST APIs](https://developer.here.com/develop/rest-apis) for that purpose. Following are some links to help you in your task:
# - To generate a free HereMaps account and an API Key to use for geocoding the addresses:
#     - https://developer.here.com/documentation/identity-access-management/dev_guide/topics/plat-using-apikeys.html
# - Sections pertaining to *geocoding* in the documentation:
#     - https://developer.here.com/documentation/geocoder/dev_guide/topics/example-geocoding-free-form.html
#     - https://developer.here.com/documentation/geocoder/dev_guide/topics/example-geocoding-intersection.html
# - Programmatically perform GET requests
#     - Python: https://realpython.com/python-requests/
#     - R: https://www.rdocumentation.org/packages/httr/versions/1.4.4
#
# Note that HereMaps allows a maximum of 1000 requests per day, so it will take more than a single day to do all the geocoding. As a start, you may use all bus stops (~120 stops) and a few hundred employee addresses to start developing your algorithm. Save whatever you geocode so you would not need to geocode it again. Once the geocoding is done for all addresses, run the algorithm one last time and finalize your work.
#
# *Side Note:*
# *The use of HereMaps API for geocoding is just one suggestion. If you are more comfortable using GoogleMaps API or OpenStreetMaps API, then you may use that as well. There are no constraints as to what you may use for geocoding of the addresses.*
#
# <BR>
# <BR>
# <center><b><u>Finally, note that we will re-run your code (without the geocoding part) to make sure that your work is reproducible.</u></b></center>
#
# <BR>
# <center>
# <H2>*** GOOD LUCK ***</H2>
# </center>

# %% [markdown]
# --------

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd 
import numpy as np
import requests
import json

import matplotlib.pyplot as plt 
# %matplotlib inline
import plotly.graph_objects as go

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestCentroid
from sklearn.mixture import GaussianMixture
from scipy.stats import multivariate_normal

import haversine as hs

# %% [markdown]
# ## Read Data

# %%
bus_stops = pd.read_csv("Bus_Stops.csv")
employee_addresses = pd.read_csv("Employee_Addresses.csv")

# %% [markdown]
# ## Exploring Data

# %%
print("Bus stops shape: ", bus_stops.shape)
bus_stops.head()
# Out:
# Bus stops shape:  (119, 2)
#    Street_One         Street_Two
# 0  MISSION ST          ITALY AVE
# 1  MISSION ST  NEW MONTGOMERY ST
# 2  MISSION ST            01ST ST
# 3  MISSION ST            20TH ST
# 4  MISSION ST         FREMONT ST

# %%
print("Employee addresses shape: ", bus_stops.shape)
employee_addresses.head()
# Out:
# Employee addresses shape:  (119, 2)
#                                           address  employee_id
# 0   98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1        237 Accacia St, Daly City, CA 94014, USA         2081
# 2    1835 Folsom St, San Francisco, CA 94103, USA          178
# 3  170 Cambridge St, San Francisco, CA 94134, USA           50
# 4     16 Roanoke St, San Francisco, CA 94131, USA         1863

# %%
bus_stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Street_One  119 non-null    object
#  1   Street_Two  119 non-null    object
# dtypes: object(2)
# memory usage: 2.0+ KB

# %%
employee_addresses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191 entries, 0 to 2190
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   address      2191 non-null   object
#  1   employee_id  2191 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 34.4+ KB

# %% [markdown]
# There are no missing data

# %% [markdown]
# ### Checking for duplicates

# %%
bus_stops.duplicated(keep='last').tail()
# Out:
# 114    False
# 115    False
# 116    False
# 117    False
# 118    False
# dtype: bool

# %%
employee_addresses.duplicated(keep='last').tail()
# Out:
# 2186    False
# 2187    False
# 2188    False
# 2189    False
# 2190    False
# dtype: bool

# %% [markdown]
# There are no duplicates in the two dataframes

# %% [markdown]
# ### preparing the bus stops data for geocoding

# %%
# check if there are values starts with 0, and remove the 0 -> to better geocoding  
for index, val in bus_stops['Street_Two'].iteritems():
    if val[0] == '0':
        bus_stops.at[index, 'Street_Two'] = val[1:]
        
bus_stops['address'] = bus_stops['Street_One'] + ', ' + bus_stops['Street_Two']

# %%
bus_stops.head()
# Out:
#    Street_One         Street_Two                        address
# 0  MISSION ST          ITALY AVE          MISSION ST, ITALY AVE
# 1  MISSION ST  NEW MONTGOMERY ST  MISSION ST, NEW MONTGOMERY ST
# 2  MISSION ST             1ST ST             MISSION ST, 1ST ST
# 3  MISSION ST            20TH ST            MISSION ST, 20TH ST
# 4  MISSION ST         FREMONT ST         MISSION ST, FREMONT ST

# %% [markdown]
# ## Geocoding

# %%
def geocode_addresses(api_key, address_col, df, intersection):
    """ Geocode addresses 
    
    Arguments: 
        api_key (str): Here api key for geocoding 
        address_col (pandas series): it has the addresses 
        df (pandas dataframe): an empty data frame to store response, latitude and longitude
        intersection (bool): if we want to get the geocode for street intersection, set it to True
    
    Returns: 
        pandas dataframe that has the geocoded data 
    """
    
    url = "https://geocoder.ls.hereapi.com/6.2/geocode.json"
    
    for index, value in address_col.iteritems():
        address = value    # get address 
        print("{} {} is geocoded now ".format(index, address))
        
        # check if we want street intersection or a free-form address 
        if intersection:
            parameters = {
                'apiKey': api_key,
                'city': 'San Francisco',
                'street': address
            }
        else:
            parameters = {
                'apiKey': api_key,
                'searchtext': address
            }
            
        response = requests.get(url, params=parameters) 
        
        if (response.ok):            
            # convert the response from str to dict 
            res = json.loads(response.text)
            
            # get latitude and longitude values 
            lat = res['Response']['View'][0]['Result'][0]['Location']['DisplayPosition']['Latitude']
            lon = res['Response']['View'][0]['Result'][0]['Location']['DisplayPosition']['Longitude']
            
            # store data in the dataframe
            df.loc[len(df.index)] = [res, lat, lon]

        else:
            df.loc[len(df.index)] = [np.nan, np.nan, np.nan]
            
    return df

# %% [markdown]
# ### Geocode bus stops

# %%
# creating new empty datafram to store response, latitude and longitude for each address 
bus_stops_gecoded = pd.DataFrame(columns=['response', 'latitude', 'longitude'])

# %%
bus_stops_gecoded.head()
# Out:
# Empty DataFrame
# Columns: [response, latitude, longitude]
# Index: []

# %%
api_key = "Fw5VNn0p2uS6vbH90MI6q_1ocMhR6iN_X5ZVGxBGQDc"
bus_stops_gecoded = geocode_addresses(api_key, bus_stops['address'], bus_stops_gecoded, intersection=True)
# Out:
# 0 MISSION ST, ITALY AVE is geocoded now
# 1 MISSION ST, NEW MONTGOMERY ST is geocoded now
# 2 MISSION ST, 1ST ST is geocoded now
# 3 MISSION ST, 20TH ST is geocoded now
# 4 MISSION ST, FREMONT ST is geocoded now
# 5 MISSION ST, 13TH ST is geocoded now
# 6 MISSION ST, ERIE ST is geocoded now
# 7 MISSION ST, BEALE ST is geocoded now
# 8 MISSION ST, FAIR AVE is geocoded now
# 9 MISSION ST, SAINT MARYS AVE is geocoded now
# 10 MISSION ST, SENECA AVE is geocoded now
# 11 MISSION ST, ANTHONY ST is geocoded now
# 12 MISSION ST, JESSIE EAST ST is geocoded now
# 13 MISSION ST, SILVER AVE is geocoded now
# 14 MISSION ST, MOUNT VERNON AVE is geocoded now
# 15 MISSION ST, 30TH ST is geocoded now
# 16 MISSION ST, MAIN ST is geocoded now
# 17 MISSION ST, TRUMBULL ST is geocoded now
# 18 MISSION ST, 15TH ST is geocoded now
# 19 MISSION ST, KINGSTON ST is geocoded now
# 20 MISSION ST, TINGLEY ST is geocoded now
# 21 MISSION ST, THERESA ST is geocoded now
# 22 MISSION ST, PARK ST is geocoded now
# 23 MISSION ST, OLIVER ST is geocoded now
# 24 MISSION ST, STEUART ST is geocoded now
# 25 MISSION ST, HURON AVE is geocoded now
# 26 MISSION ST, SYCAMORE ST is geocoded now
# 27 MISSION ST, 2ND ST is geocoded now
# 28 MISSION ST, MINT ST is geocoded now
# 29 MISSION ST, GENEVA AVE is geocoded now
# 30 MISSION ST, CORTLAND AVE is geocoded now
# 31 MISSION ST, 22ND ST is geocoded now
# 32 MISSION ST, 6TH ST is geocoded now
# 33 MISSION ST, PRECITA AVE is geocoded now
# 34 MISSION ST, 17TH ST is geocoded now
# 35 MISSION ST, CASTLE MANOR AVE is geocoded now
# 36 MISSION ST, ALLISON ST is geocoded now
# 37 MISSION ST, 26TH ST is geocoded now
# 38 MISSION ST, VIRGINIA AVE is geocoded now
# 39 MISSION ST, COTTER ST is geocoded now
# 40 MISSION ST, WHIPPLE AVE is geocoded now
# 41 MISSION ST, 8TH ST is geocoded now
# 42 MISSION ST, PLUM ST is geocoded now
# 43 MISSION ST, THE EMBARCADERO is geocoded now
# 44 MISSION ST, 19TH ST is geocoded now
# 45 MISSION ST, APPLETON AVE is geocoded now
# 46 MISSION ST, OCEAN AVE is geocoded now
# 47 MISSION ST, GODEUS ST is geocoded now
# 48 MISSION ST, POPE ST is geocoded now
# 49 MISSION ST, FARRAGUT AVE is geocoded now
# 50 MISSION ST, 11TH ST is geocoded now
# 51 MISSION ST, EUGENIA AVE is geocoded now
# 52 MISSION ST, 4TH ST is geocoded now
# 53 MISSION ST, FRANCE AVE is geocoded now
# 54 MISSION ST, LASKIE ST is geocoded now
# 55 MISSION ST, 29TH ST is geocoded now
# 56 MISSION ST, RUSSIA AVE is geocoded now
# 57 MISSION ST, ONONDAGA AVE is geocoded now
# 58 MISSION ST, ANNIE ST is geocoded now
# 59 MISSION ST, 21ST ST is geocoded now
# 60 MISSION ST, CLARION ALY is geocoded now
# 61 MISSION ST, NAGLEE AVE is geocoded now
# 62 MISSION ST, ADMIRAL AVE is geocoded now
# 63 MISSION ST, RICHLAND AVE is geocoded now
# 64 MISSION ST, LOWELL ST is geocoded now
# 65 MISSION ST, SAN JUAN AVE is geocoded now
# 66 MISSION ST, 14TH ST is geocoded now
# 67 MISSION ST, CONCORD ST is geocoded now
# 68 MISSION ST, HIGHLAND AVE is geocoded now
# 69 MISSION ST, 10TH ST is geocoded now
# 70 MISSION ST, LAWRENCE AVE is geocoded now
# 71 MISSION ST, AMAZON AVE is geocoded now
# 72 MISSION ST, ECKER ST is geocoded now
# 73 MISSION ST, SHAW ALY is geocoded now
# 74 MISSION ST, AVALON AVE is geocoded now
# 75 MISSION ST, FRANCIS ST is geocoded now
# 76 MISSION ST, LAFAYETTE ST is geocoded now
# 77 MISSION ST, JESSIE WEST ST is geocoded now
# 78 MISSION ST, COLLEGE AVE is geocoded now
# 79 MISSION ST, 3RD ST is geocoded now
# 80 MISSION ST, HARRINGTON ST is geocoded now
# 81 MISSION ST, COLLEGE TER is geocoded now
# 82 MISSION ST, VALENCIA ST is geocoded now
# 83 MISSION ST, NEY ST is geocoded now
# 84 MISSION ST, 12TH ST is geocoded now
# 85 MISSION ST, 25TH ST is geocoded now
# 86 MISSION ST, MARY ST is geocoded now
# 87 MISSION ST, SPEAR ST is geocoded now
# 88 MISSION ST, ROLPH ST is geocoded now
# 89 MISSION ST, 7TH ST is geocoded now
# 90 MISSION ST, NORTON ST is geocoded now
# 91 MISSION ST, RUTH ST is geocoded now
# 92 MISSION ST, BRAZIL AVE is geocoded now
# 93 MISSION ST, GUTTENBERG ST is geocoded now
# 94 MISSION ST, 23RD ST is geocoded now
# 95 MISSION ST, RANDALL ST is geocoded now
# 96 MISSION ST, PERSIA AVE is geocoded now
# 97 MISSION ST, 16TH ST is geocoded now
# 98 MISSION ST, YERBA BUENA LN is geocoded now
# 99 MISSION ST, LAURA ST is geocoded now
# 100 MISSION ST, 18TH ST is geocoded now
# 101 MISSION ST, LEO ST is geocoded now
# 102 MISSION ST, POWERS AVE is geocoded now
# 103 MISSION ST, SANTA ROSA AVE is geocoded now
# 104 MISSION ST, FLORENTINE AVE is geocoded now
# 105 MISSION ST, FOOTE AVE is geocoded now
# 106 MISSION ST, BOSWORTH ST is geocoded now
# 107 MISSION ST, EXCELSIOR AVE is geocoded now
# 108 MISSION ST, WASHBURN ST is geocoded now
# 109 MISSION ST, MORSE ST is geocoded now
# 110 MISSION ST, ANGELOS ALY is geocoded now
# 111 MISSION ST, BROOK ST is geocoded now
# 112 MISSION ST, 9TH ST is geocoded now
# 113 MISSION ST, OTTAWA AVE is geocoded now
# 114 MISSION ST, NIAGARA AVE is geocoded now
# 115 MISSION ST, ACTON ST is geocoded now
# 116 MISSION ST, 5TH ST is geocoded now
# 117 MISSION ST, 24TH ST is geocoded now
# 118 MISSION ST, GRACE ST is geocoded now

# %%
bus_stops_gecoded.head()
# Out:
#                                             response  latitude  longitude
# 0  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.71675 -122.43594
# 1  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78747 -122.40052
# 2  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.77867 -122.41160
# 3  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.75887 -122.41513
# 4  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78987 -122.39595

# %%
bus_stops_gecoded.to_csv("bus_stops_gecoded.csv")

# %%
bus_stops = pd.concat([bus_stops, bus_stops_gecoded], axis=1)

# %%
bus_stops.head()
# Out:
#    Street_One         Street_Two                        address  \
# 0  MISSION ST          ITALY AVE          MISSION ST, ITALY AVE
# 1  MISSION ST  NEW MONTGOMERY ST  MISSION ST, NEW MONTGOMERY ST
# 2  MISSION ST             1ST ST             MISSION ST, 1ST ST
# 3  MISSION ST            20TH ST            MISSION ST, 20TH ST
# 4  MISSION ST         FREMONT ST         MISSION ST, FREMONT ST
#
#                                             response  latitude  longitude
# 0  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.71675 -122.43594
# 1  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78747 -122.40052
# 2  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.77867 -122.41160
# 3  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.75887 -122.41513
# 4  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78987 -122.39595

# %% [markdown]
# ### Geocode employee addresses

# %%
employee_addresses_gecoded = pd.DataFrame(columns=['response', 'latitude', 'longitude'])

# %%
employee_addresses_gecoded
# Out:
# Empty DataFrame
# Columns: [response, latitude, longitude]
# Index: []

# %%
employee_addresses['address']
# Out:
# 0        98 Edinburgh St, San Francisco, CA 94112, USA
# 1             237 Accacia St, Daly City, CA 94014, USA
# 2         1835 Folsom St, San Francisco, CA 94103, USA
# 3       170 Cambridge St, San Francisco, CA 94134, USA
# 4          16 Roanoke St, San Francisco, CA 94131, USA
#                              ...
# 2186       72 Topeka Ave, San Francisco, CA 94124, USA
# 2187           330 Oliver St, Daly City, CA 94014, USA
# 2188       94 W View Ave, San Francisco, CA 94134, USA
# 2189     1599 Geneva Ave, San Francisco, CA 94112, USA
# 2190       499 Treat Ave, San Francisco, CA 94110, USA
# Name: address, Length: 2191, dtype: object

# %%
api_key = "Fw5VNn0p2uS6vbH90MI6q_1ocMhR6iN_X5ZVGxBGQDc"
employee_addresses_gecoded = geocode_addresses(api_key, employee_addresses['address'], employee_addresses_gecoded, intersection=False)
# Out:
# 0 98 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 1 237 Accacia St, Daly City, CA 94014, USA is geocoded now
# 2 1835 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 3 170 Cambridge St, San Francisco, CA 94134, USA is geocoded now
# 4 16 Roanoke St, San Francisco, CA 94131, USA is geocoded now
# 5 222 Whittier St, Daly City, CA 94014, USA is geocoded now
# 6 13 Hyde St, San Francisco, CA 94102, USA is geocoded now
# 7 2919 Geneva Ave, Daly City, CA 94014, USA is geocoded now
# 8 100 Larkin St, San Francisco, CA 94102, USA is geocoded now
# 9 230 Murray St, San Francisco, CA 94112, USA is geocoded now
# 10 45 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 11 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 12 838 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 13 2111 Revere Ave, San Francisco, CA 94124, USA is geocoded now
# 14 435 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 15 80 Risel Ave, Daly City, CA 94014, USA is geocoded now
# 16 928 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 17 2711 Scott St, San Francisco, CA 94123, USA is geocoded now
# 18 801 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 19 201 Schwerin St, San Francisco, CA 94134, USA is geocoded now
# 20 645 Harrison St, San Francisco, CA 94107, USA is geocoded now
# 21 1560 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 22 98 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 23 160 Charter Oak Ave, San Francisco, CA 94124, USA is geocoded now
# 24 53 Everson St, San Francisco, CA 94131, USA is geocoded now
# 25 869 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 26 3380 Mission St, San Francisco, CA 94110, USA is geocoded now
# 27 2435 Union St, San Francisco, CA 94123, USA is geocoded now
# 28 43 Ervine St, San Francisco, CA 94134, USA is geocoded now
# 29 555 9th St, San Francisco, CA 94103, USA is geocoded now
# 30 1169 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 31 16 Navajo Ave, San Francisco, CA 94112, USA is geocoded now
# 32 3178 17th St, San Francisco, CA 94110, USA is geocoded now
# 33 125 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 34 55 Curtis St, San Francisco, CA 94112, USA is geocoded now
# 35 2697 Union St, San Francisco, CA 94123, USA is geocoded now
# 36 669 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 37 431 Murray St, San Francisco, CA 94110, USA is geocoded now
# 38 3048 Geneva Ave, Daly City, CA 94014, USA is geocoded now
# 39 2498 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 40 1923 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 41 146 Valley St, San Francisco, CA 94131, USA is geocoded now
# 42 1608 Felton St, San Francisco, CA 94134, USA is geocoded now
# 43 35 Santa Fe Ave, San Francisco, CA 94124, USA is geocoded now
# 44 330 Harvard St, San Francisco, CA 94134, USA is geocoded now
# 45 231 Duncan St, San Francisco, CA 94131, USA is geocoded now
# 46 335 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 47 924 Naples St, San Francisco, CA 94112, USA is geocoded now
# 48 59 Risel Ave, Daly City, CA 94014, USA is geocoded now
# 49 895 Foerster St, San Francisco, CA 94127, USA is geocoded now
# 50 157 Noe St, San Francisco, CA 94114, USA is geocoded now
# 51 600 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 52 661 Twin Peaks Blvd, San Francisco, CA 94114, USA is geocoded now
# 53 15 Boutwell St, San Francisco, CA 94124, USA is geocoded now
# 54 72 Risel Ave, Daly City, CA 94014, USA is geocoded now
# 55 777 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 56 135 Morse St, San Francisco, CA 94112, USA is geocoded now
# 57 210 Alemany Blvd, San Francisco, CA 94134, USA is geocoded now
# 58 86A Conkling St, San Francisco, CA 94124, USA is geocoded now
# 59 562 Ellington Ave, San Francisco, CA 94112, USA is geocoded now
# 60 2760 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 61 52 Isis St, San Francisco, CA 94103, USA is geocoded now
# 62 29 Athens St, San Francisco, CA 94112, USA is geocoded now
# 63 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 64 650 Harrison St, San Francisco, CA 94107, USA is geocoded now
# 65 324 Frankfort St, Daly City, CA 94014, USA is geocoded now
# 66 45 Joost Ave, San Francisco, CA 94131, USA is geocoded now
# 67 94 Addison St, San Francisco, CA 94131, USA is geocoded now
# 68 56 Curtis St, San Francisco, CA 94112, USA is geocoded now
# 69 1600 15th St, San Francisco, CA 94103, USA is geocoded now
# 70 148 29th St, San Francisco, CA 94110, USA is geocoded now
# 71 61 Valley St, San Francisco, CA 94110, USA is geocoded now
# 72 1619 13th St, San Francisco, CA 94103, USA is geocoded now
# 73 531 College Ave, San Francisco, CA 94112, USA is geocoded now
# 74 2032 Revere Ave, San Francisco, CA 94124, USA is geocoded now
# 75 1183 Munich St, San Francisco, CA 94112, USA is geocoded now
# 76 100 Polk St, San Francisco, CA 94102, USA is geocoded now
# 77 303 2nd St, San Francisco, CA 94107, USA is geocoded now
# 78 510 Bellevue Ave, Daly City, CA 94014, USA is geocoded now
# 79 243 Oriente St, Daly City, CA 94014, USA is geocoded now
# 80 2698 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 81 120 Cuvier St, San Francisco, CA 94112, USA is geocoded now
# 82 738 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 83 417 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 84 34 Britton St, San Francisco, CA 94134, USA is geocoded now
# 85 1830 Harrison St, San Francisco, CA 94103, USA is geocoded now
# 86 299 Utah St, San Francisco, CA 94103, USA is geocoded now
# 87 80, San Francisco, CA 94105, USA is geocoded now
# 88 1798 Visitacion Ave, San Francisco, CA 94134, USA is geocoded now
# 89 2949 Divisadero St, San Francisco, CA 94123, USA is geocoded now
# 90 45 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 91 33 Gambier St, San Francisco, CA 94134, USA is geocoded now
# 92 417 Rolph St, San Francisco, CA 94112, USA is geocoded now
# 93 98 Norfolk St, San Francisco, CA 94103, USA is geocoded now
# 94 270 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 95 43 Woodward St, San Francisco, CA 94103, USA is geocoded now
# 96 966 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 97 114 Rousseau St, San Francisco, CA 94112, USA is geocoded now
# 98 241 Excelsior Ave, San Francisco, CA 94112, USA is geocoded now
# 99 416 Leland Ave, San Francisco, CA 94134, USA is geocoded now
# 100 131 Milton St, San Francisco, CA 94112, USA is geocoded now
# 101 56 Mercury St, San Francisco, CA 94124, USA is geocoded now
# 102 1932 Baker St, San Francisco, CA 94115, USA is geocoded now
# 103 1499 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 104 2716 Pacific Ave, San Francisco, CA 94115, USA is geocoded now
# 105 98 Erie St, San Francisco, CA 94103, USA is geocoded now
# 106 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 107 6 Mateo St, San Francisco, CA 94131, USA is geocoded now
# 108 1433 Silliman St, San Francisco, CA 94134, USA is geocoded now
# 109 680 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 110 1200 15th St, San Francisco, CA 94103, USA is geocoded now
# 111 899 14th St, San Francisco, CA 94114, USA is geocoded now
# 112 36 Maynard St, San Francisco, CA 94112, USA is geocoded now
# 113 518 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 114 3380 Mission St, San Francisco, CA 94110, USA is geocoded now
# 115 140 Charter Oak Ave, San Francisco, CA 94124, USA is geocoded now
# 116 720 Morse St, San Francisco, CA 94112, USA is geocoded now
# 117 2150 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 118 631 Hanover St, Daly City, CA 94014, USA is geocoded now
# 119 1690 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 120 502 Naples St, San Francisco, CA 94112, USA is geocoded now
# 121 166 Oxford St, San Francisco, CA 94134, USA is geocoded now
# 122 835 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 123 45 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 124 1131 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 125 2166 Market St, San Francisco, CA 94114, USA is geocoded now
# 126 326 Hampshire St, San Francisco, CA 94110, USA is geocoded now
# 127 114 Crescent Ave, San Francisco, CA 94110, USA is geocoded now
# 128 925 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 129 318 Excelsior Ave, San Francisco, CA 94112, USA is geocoded now
# 130 299 Melrose Ave, San Francisco, CA 94127, USA is geocoded now
# 131 41 Britton St, San Francisco, CA 94134, USA is geocoded now
# 132 233 Pope St, San Francisco, CA 94112, USA is geocoded now
# 133 160 Bemis St, San Francisco, CA 94131, USA is geocoded now
# 134 200 Cordova St, San Francisco, CA 94112, USA is geocoded now
# 135 81 Tiffany Ave, San Francisco, CA 94110, USA is geocoded now
# 136 45 Wilder St, San Francisco, CA 94131, USA is geocoded now
# 137 3099 Washington St, San Francisco, CA 94115, USA is geocoded now
# 138 50 Tiffany Ave, San Francisco, CA 94110, USA is geocoded now
# 139 13th St, San Francisco, CA 94103, USA is geocoded now
# 140 574 Campbell Ave, San Francisco, CA 94134, USA is geocoded now
# 141 5601 Mission St, San Francisco, CA 94112, USA is geocoded now
# 142 474 Naples St, San Francisco, CA 94112, USA is geocoded now
# 143 1574 Howard St, San Francisco, CA 94103, USA is geocoded now
# 144 717 Delta St, San Francisco, CA 94134, USA is geocoded now
# 145 1695 Mission St, San Francisco, CA 94103, USA is geocoded now
# 146 2399 Greenwich St, San Francisco, CA 94123, USA is geocoded now
# 147 1532 Silliman St, San Francisco, CA 94134, USA is geocoded now
# 148 281 Oriente St, Daly City, CA 94014, USA is geocoded now
# 149 360 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 150 2544 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 151 517 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 152 390 Melrose Ave, San Francisco, CA 94127, USA is geocoded now
# 153 3002 Pierce St, San Francisco, CA 94115, USA is geocoded now
# 154 455 Golden Gate Ave, San Francisco, CA 94102, USA is geocoded now
# 155 69 Madison St, San Francisco, CA 94134, USA is geocoded now
# 156 1060 Brannan St, San Francisco, CA 94103, USA is geocoded now
# 157 564 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 158 1818 Silver Ave, San Francisco, CA 94124, USA is geocoded now
# 159 446 Moscow St, San Francisco, CA 94112, USA is geocoded now
# 160 875 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 161 826 14th St, San Francisco, CA 94114, USA is geocoded now
# 162 2055 Folsom St, San Francisco, CA 94110, USA is geocoded now
# 163 301 Amazon Ave, San Francisco, CA 94112, USA is geocoded now
# 164 138 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 165 2112 15th St, San Francisco, CA 94114, USA is geocoded now
# 166 188 Elliot St, San Francisco, CA 94134, USA is geocoded now
# 167 2975 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 168 1606 Guerrero St, San Francisco, CA 94110, USA is geocoded now
# 169 38 Walter St, San Francisco, CA 94114, USA is geocoded now
# 170 310 Alemany Blvd, San Francisco, CA 94110, USA is geocoded now
# 171 149 Paris St, San Francisco, CA 94112, USA is geocoded now
# 172 198 Church St, San Francisco, CA 94114, USA is geocoded now
# 173 98 Norfolk St, San Francisco, CA 94103, USA is geocoded now
# 174 260 Acton St, Daly City, CA 94014, USA is geocoded now
# 175 1656 15th St, San Francisco, CA 94103, USA is geocoded now
# 176 115 Tiffany Ave, San Francisco, CA 94110, USA is geocoded now
# 177 807 Bosworth St, San Francisco, CA 94131, USA is geocoded now
# 178 366 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 179 661 Twin Peaks Blvd, San Francisco, CA 94114, USA is geocoded now
# 180 430 Leland Ave, San Francisco, CA 94134, USA is geocoded now
# 181 42 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 182 1 Naylor St, San Francisco, CA 94112, USA is geocoded now
# 183 598 14th St, San Francisco, CA 94103, USA is geocoded now
# 184 934 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 185 1643 Quint St, San Francisco, CA 94124, USA is geocoded now
# 186 699 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 187 2154 16th St, San Francisco, CA 94103, USA is geocoded now
# 188 30 Bernice St, San Francisco, CA 94103, USA is geocoded now
# 189 290 Richland Ave, San Francisco, CA 94110, USA is geocoded now
# 190 5620 Mission St, San Francisco, CA 94112, USA is geocoded now
# 191 1606 Guerrero St, San Francisco, CA 94110, USA is geocoded now
# 192 376 Madison St, San Francisco, CA 94134, USA is geocoded now
# 193 876 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 194 2545 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 195 820 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 196 709 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 197 499 Van Ness Ave, San Francisco, CA 94102, USA is geocoded now
# 198 750 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 199 1545 San Jose Avenue, San Francisco, CA 94112, USA is geocoded now
# 200 45 Conkling St, San Francisco, CA 94124, USA is geocoded now
# 201 238 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 202 92 Conkling St, San Francisco, CA 94124, USA is geocoded now
# 203 975 Athens St, San Francisco, CA 94112, USA is geocoded now
# 204 24 Addison St, San Francisco, CA 94131, USA is geocoded now
# 205 1545 San Jose Avenue, San Francisco, CA 94112, USA is geocoded now
# 206 125 Excelsior Ave, San Francisco, CA 94112, USA is geocoded now
# 207 2 Everson St, San Francisco, CA 94131, USA is geocoded now
# 208 158 Boutwell St, San Francisco, CA 94124, USA is geocoded now
# 209 2273 16th St, San Francisco, CA 94103, USA is geocoded now
# 210 69 Bemis St, San Francisco, CA 94131, USA is geocoded now
# 211 855 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 212 121 Tiffany Ave, San Francisco, CA 94110, USA is geocoded now
# 213 194 Park St, San Francisco, CA 94110, USA is geocoded now
# 214 3200 Washington St, San Francisco, CA 94115, USA is geocoded now
# 215 124 Leese St, San Francisco, CA 94110, USA is geocoded now
# 216 1750 Harrison St, San Francisco, CA 94103, USA is geocoded now
# 217 158 27th St, San Francisco, CA 94110, USA is geocoded now
# 218 625 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 219 20 Curtis St, San Francisco, CA 94112, USA is geocoded now
# 220 94 Joost Ave, San Francisco, CA 94131, USA is geocoded now
# 221 3161 Sacramento St, San Francisco, CA 94115, USA is geocoded now
# 222 2273 16th St, San Francisco, CA 94103, USA is geocoded now
# 223 34 Bannock St, San Francisco, CA 94112, USA is geocoded now
# 224 2350 Green St, San Francisco, CA 94115, USA is geocoded now
# 225 307 Ottilia St, Daly City, CA 94014, USA is geocoded now
# 226 50 Fell St, San Francisco, CA 94102, USA is geocoded now
# 227 981 Athens St, San Francisco, CA 94112, USA is geocoded now
# 228 125 Hayes St, San Francisco, CA 94102, USA is geocoded now
# 229 50 Everson St, San Francisco, CA 94131, USA is geocoded now
# 230 1225 Naples St, San Francisco, CA 94112, USA is geocoded now
# 231 730 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 232 1469 Harrison St, San Francisco, CA 94103, USA is geocoded now
# 233 649 San Jose Avenue, San Francisco, CA 94110, USA is geocoded now
# 234 224 Murray St, San Francisco, CA 94112, USA is geocoded now
# 235 145 Hampshire St, San Francisco, CA 94103, USA is geocoded now
# 236 3 Maddux Ave, San Francisco, CA 94124, USA is geocoded now
# 237 551 Athens St, San Francisco, CA 94112, USA is geocoded now
# 238 685 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 239 2160 Market St, San Francisco, CA 94114, USA is geocoded now
# 240 St. Luke's Hospital Garage, San Francisco, CA 94110, USA is geocoded now
# 241 1798 Visitacion Ave, San Francisco, CA 94134, USA is geocoded now
# 242 22 Cuvier St, San Francisco, CA 94112, USA is geocoded now
# 243 155 Oriente St, Daly City, CA 94014, USA is geocoded now
# 244 3048 Geneva Ave, Daly City, CA 94014, USA is geocoded now
# 245 212 29th St, San Francisco, CA 94131, USA is geocoded now
# 246 98 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 247 137 27th St, San Francisco, CA 94110, USA is geocoded now
# 248 1174 Bryant St, San Francisco, CA 94103, USA is geocoded now
# 249 598 Bosworth St, San Francisco, CA 94131, USA is geocoded now
# 250 115 Mateo St, San Francisco, CA 94131, USA is geocoded now
# 251 1600 15th St, San Francisco, CA 94103, USA is geocoded now
# 252 2901 16th St, San Francisco, CA 94103, USA is geocoded now
# 253 1399 15th St, San Francisco, CA 94103, USA is geocoded now
# 254 134 Scotia Ave, San Francisco, CA 94124, USA is geocoded now
# 255 737 Rolph St, San Francisco, CA 94112, USA is geocoded now
# 256 2107 Lyon St, San Francisco, CA 94115, USA is geocoded now
# 257 1399 15th St, San Francisco, CA 94103, USA is geocoded now
# 258 531 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 259 135 Kissling St, San Francisco, CA 94103, USA is geocoded now
# 260 2505 Green St, San Francisco, CA 94123, USA is geocoded now
# 261 2101 Thomas Ave, San Francisco, CA 94124, USA is geocoded now
# 262 2 Pearl St, San Francisco, CA 94103, USA is geocoded now
# 263 1200 15th St, San Francisco, CA 94103, USA is geocoded now
# 264 1390 Market St, San Francisco, CA 94102, USA is geocoded now
# 265 3222 Washington St, San Francisco, CA 94115, USA is geocoded now
# 266 345 Gambier St, San Francisco, CA 94134, USA is geocoded now
# 267 151 Lippard Ave, San Francisco, CA 94131, USA is geocoded now
# 268 899 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 269 189 13th St, San Francisco, CA 94103, USA is geocoded now
# 270 98 Erie St, San Francisco, CA 94103, USA is geocoded now
# 271 1580 Valencia St, San Francisco, CA 94110, USA is geocoded now
# 272 27 Albion St, San Francisco, CA 94103, USA is geocoded now
# 273 220 Surrey St, San Francisco, CA 94131, USA is geocoded now
# 274 4271 Mission St, San Francisco, CA 94112, USA is geocoded now
# 275 1621 Howard St, San Francisco, CA 94103, USA is geocoded now
# 276 2635 Scott St, San Francisco, CA 94123, USA is geocoded now
# 277 545 Delta St, San Francisco, CA 94134, USA is geocoded now
# 278 124 Oriente St, Daly City, CA 94014, USA is geocoded now
# 279 722 Sweeny St, San Francisco, CA 94134, USA is geocoded now
# 280 869 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 281 124 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 282 421 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 283 1835 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 284 708 Acton St, Daly City, CA 94014, USA is geocoded now
# 285 399 14th St, San Francisco, CA 94103, USA is geocoded now
# 286 318 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 287 2044 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 288 15 Britton St, San Francisco, CA 94134, USA is geocoded now
# 289 384 Gambier St, San Francisco, CA 94134, USA is geocoded now
# 290 153 London St, San Francisco, CA 94112, USA is geocoded now
# 291 44 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 292 1665 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 293 258 Harvard St, San Francisco, CA 94134, USA is geocoded now
# 294 850 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 295 400 Treat Ave, San Francisco, CA 94110, USA is geocoded now
# 296 501 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 297 170 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 298 1940 Harrison St, San Francisco, CA 94103, USA is geocoded now
# 299 1144 Munich St, San Francisco, CA 94112, USA is geocoded now
# 300 2425 Alameda St, San Francisco, CA 94103, USA is geocoded now
# 301 319 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 302 123 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 303 166 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 304 981 Athens St, San Francisco, CA 94112, USA is geocoded now
# 305 1272 Market St, San Francisco, CA 94102, USA is geocoded now
# 306 126 London St, San Francisco, CA 94112, USA is geocoded now
# 307 222 Seneca Ave, San Francisco, CA 94112, USA is geocoded now
# 308 242 Lowell St, San Francisco, CA 94112, USA is geocoded now
# 309 781 Prague St, San Francisco, CA 94112, USA is geocoded now
# 310 1581 Dolores St, San Francisco, CA 94110, USA is geocoded now
# 311 300 Leland Ave, San Francisco, CA 94134, USA is geocoded now
# 312 28 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 313 St. Luke's Hospital Garage, San Francisco, CA 94110, USA is geocoded now
# 314 2600 Union St, San Francisco, CA 94123, USA is geocoded now
# 315 440 Hanover St, San Francisco, CA 94112, USA is geocoded now
# 316 599 Bosworth St, San Francisco, CA 94131, USA is geocoded now
# 317 2345 Filbert St, San Francisco, CA 94123, USA is geocoded now
# 318 598 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 319 6 Madison St, San Francisco, CA 94134, USA is geocoded now
# 320 11 Roanoke St, San Francisco, CA 94131, USA is geocoded now
# 321 524 Moscow St, San Francisco, CA 94112, USA is geocoded now
# 322 501 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 323 891 Foerster St, San Francisco, CA 94127, USA is geocoded now
# 324 3201 Clay St, San Francisco, CA 94115, USA is geocoded now
# 325 166 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 326 2017 Lyon St, San Francisco, CA 94115, USA is geocoded now
# 327 188 Elliot St, San Francisco, CA 94134, USA is geocoded now
# 328 2098 Folsom St, San Francisco, CA 94110, USA is geocoded now
# 329 1773 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 330 5098 Mission St, San Francisco, CA 94112, USA is geocoded now
# 331 1331 Harrison St, San Francisco, CA 94103, USA is geocoded now
# 332 3021 Washington St, San Francisco, CA 94115, USA is geocoded now
# 333 555 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 334 535 Mangels Ave, San Francisco, CA 94127, USA is geocoded now
# 335 136 Duncan St, San Francisco, CA 94110, USA is geocoded now
# 336 343 Raymond Ave, San Francisco, CA 94134, USA is geocoded now
# 337 421 Avalon Ave, San Francisco, CA 94112, USA is geocoded now
# 338 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 339 1975 Market St, San Francisco, CA 94103, USA is geocoded now
# 340 140 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 341 31 27th St, San Francisco, CA 94110, USA is geocoded now
# 342 730 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 343 1062 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 344 1230 Visitacion Ave, San Francisco, CA 94134, USA is geocoded now
# 345 2039 Silver Ave, San Francisco, CA 94124, USA is geocoded now
# 346 180 Bemis St, San Francisco, CA 94131, USA is geocoded now
# 347 751 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 348 299 Murray St, San Francisco, CA 94112, USA is geocoded now
# 349 52 Day St, San Francisco, CA 94110, USA is geocoded now
# 350 2041 Lyon St, San Francisco, CA 94115, USA is geocoded now
# 351 428 Lowell St, San Francisco, CA 94112, USA is geocoded now
# 352 55 Erie St, San Francisco, CA 94103, USA is geocoded now
# 353 827 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 354 2166 Market St, San Francisco, CA 94114, USA is geocoded now
# 355 2661 Green St, San Francisco, CA 94123, USA is geocoded now
# 356 48 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 357 583 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 358 2201 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 359 3150 California St, San Francisco, CA 94115, USA is geocoded now
# 360 302 Acton St, Daly City, CA 94014, USA is geocoded now
# 361 1576 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 362 2460 Green St, San Francisco, CA 94115, USA is geocoded now
# 363 303 Ottilia St, Daly City, CA 94014, USA is geocoded now
# 364 1800 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 365 240 Shotwell St, San Francisco, CA 94110, USA is geocoded now
# 366 99 Shotwell St, San Francisco, CA 94103, USA is geocoded now
# 367 3108 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 368 439 Templeton Ave, Daly City, CA 94014, USA is geocoded now
# 369 4173 Mission St, San Francisco, CA 94112, USA is geocoded now
# 370 2899 16th St, San Francisco, CA 94103, USA is geocoded now
# 371 439 Bellevue Ave, Daly City, CA 94014, USA is geocoded now
# 372 55 Potomac St, San Francisco, CA 94117, USA is geocoded now
# 373 6 Van Buren St, San Francisco, CA 94131, USA is geocoded now
# 374 1583 Dolores St, San Francisco, CA 94110, USA is geocoded now
# 375 567 Athens St, San Francisco, CA 94112, USA is geocoded now
# 376 1198 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 377 399 Hampshire St, San Francisco, CA 94110, USA is geocoded now
# 378 361 Frankfort St, Daly City, CA 94014, USA is geocoded now
# 379 399 Hampshire St, San Francisco, CA 94110, USA is geocoded now
# 380 119 Utah St, San Francisco, CA 94103, USA is geocoded now
# 381 360 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 382 1480 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 383 105 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 384 102 Cordova St, San Francisco, CA 94112, USA is geocoded now
# 385 68 Arnold Ave, San Francisco, CA 94110, USA is geocoded now
# 386 70 Everson St, San Francisco, CA 94131, USA is geocoded now
# 387 398 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 388 1685 Bryant St, San Francisco, CA 94103, USA is geocoded now
# 389 161 Boutwell St, San Francisco, CA 94124, USA is geocoded now
# 390 976 Athens St, San Francisco, CA 94112, USA is geocoded now
# 391 398 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 392 283 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 393 299 Raymond Ave, San Francisco, CA 94134, USA is geocoded now
# 394 40 Everson St, San Francisco, CA 94131, USA is geocoded now
# 395 115 Mateo St, San Francisco, CA 94131, USA is geocoded now
# 396 1101 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 397 54 Valley St, San Francisco, CA 94110, USA is geocoded now
# 398 551 Presidio Blvd, San Francisco, CA 94129, USA is geocoded now
# 399 3016 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 400 1050 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 401 230 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 402 109 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 403 1690 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 404 122 Paris St, San Francisco, CA 94112, USA is geocoded now
# 405 1200 15th St, San Francisco, CA 94103, USA is geocoded now
# 406 225 Schwerin St, San Francisco, CA 94134, USA is geocoded now
# 407 3198 17th St, San Francisco, CA 94110, USA is geocoded now
# 408 610 Thornton Ave, San Francisco, CA 94124, USA is geocoded now
# 409 449 Templeton Ave, Daly City, CA 94014, USA is geocoded now
# 410 92 Waterville St, San Francisco, CA 94124, USA is geocoded now
# 411 633 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 412 2621 Divisadero St, San Francisco, CA 94123, USA is geocoded now
# 413 36 Addison St, San Francisco, CA 94131, USA is geocoded now
# 414 75 Santa Fe Ave, San Francisco, CA 94124, USA is geocoded now
# 415 512 Arlington St, San Francisco, CA 94131, USA is geocoded now
# 416 99 Conkling St, San Francisco, CA 94124, USA is geocoded now
# 417 25 Lippard Ave, San Francisco, CA 94131, USA is geocoded now
# 418 21 Noe St, San Francisco, CA 94114, USA is geocoded now
# 419 455 Golden Gate Ave, San Francisco, CA 94102, USA is geocoded now
# 420 899 Moscow St, San Francisco, CA 94112, USA is geocoded now
# 421 183 Oxford St, San Francisco, CA 94134, USA is geocoded now
# 422 728 Brunswick St, San Francisco, CA 94112, USA is geocoded now
# 423 658 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 424 1390 Market St, San Francisco, CA 94102, USA is geocoded now
# 425 48 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 426 250 Valencia St, San Francisco, CA 94103, USA is geocoded now
# 427 792 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 428 312 Leland Ave, San Francisco, CA 94134, USA is geocoded now
# 429 21 Lyell St, San Francisco, CA 94112, USA is geocoded now
# 430 439 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 431 55 Verna St, San Francisco, CA 94127, USA is geocoded now
# 432 227 Accacia St, Daly City, CA 94014, USA is geocoded now
# 433 18 Miguel St, San Francisco, CA 94131, USA is geocoded now
# 434 1623 Silliman St, San Francisco, CA 94134, USA is geocoded now
# 435 110 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 436 110 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 437 39 Alemany Blvd, San Francisco, CA 94124, USA is geocoded now
# 438 258 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 439 3172 Sacramento St, San Francisco, CA 94115, USA is geocoded now
# 440 1798 Felton St, San Francisco, CA 94134, USA is geocoded now
# 441 2509 Filbert St, San Francisco, CA 94123, USA is geocoded now
# 442 373 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 443 60 29th St, San Francisco, CA 94110, USA is geocoded now
# 444 615 Hanover St, Daly City, CA 94014, USA is geocoded now
# 445 3035 Pacific Ave, San Francisco, CA 94115, USA is geocoded now
# 446 4173 Mission St, San Francisco, CA 94112, USA is geocoded now
# 447 25 Curtis St, San Francisco, CA 94112, USA is geocoded now
# 448 934 Brannan St, San Francisco, CA 94103, USA is geocoded now
# 449 2940 Pacific Ave, San Francisco, CA 94115, USA is geocoded now
# 450 41 14th St, San Francisco, CA 94103, USA is geocoded now
# 451 227 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 452 498 Golden Gate Ave, San Francisco, CA 94102, USA is geocoded now
# 453 398 Augusta St, San Francisco, CA 94124, USA is geocoded now
# 454 140 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 455 201 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 456 58 Roscoe St, San Francisco, CA 94110, USA is geocoded now
# 457 231 Harvard St, San Francisco, CA 94134, USA is geocoded now
# 458 810 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 459 281 Oriente St, Daly City, CA 94014, USA is geocoded now
# 460 4 S Hill Blvd, San Francisco, CA 94112, USA is geocoded now
# 461 1149 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 462 2037 Revere Ave, San Francisco, CA 94124, USA is geocoded now
# 463 111 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 464 224 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 465 2524 Greenwich St, San Francisco, CA 94123, USA is geocoded now
# 466 208 Utah St, San Francisco, CA 94103, USA is geocoded now
# 467 333 College Ave, San Francisco, CA 94112, USA is geocoded now
# 468 207 Oriente St, Daly City, CA 94014, USA is geocoded now
# 469 150 Hampshire St, San Francisco, CA 94103, USA is geocoded now
# 470 2121 Lyon St, San Francisco, CA 94115, USA is geocoded now
# 471 331 Gambier St, San Francisco, CA 94134, USA is geocoded now
# 472 69A Potomac St, San Francisco, CA 94117, USA is geocoded now
# 473 702 15th St, San Francisco, CA 94103, USA is geocoded now
# 474 San Francisco War Memorial and Performing Arts Center, 301 Van Ness Ave, San Francisco, CA 94102, USA is geocoded now
# 475 120 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 476 66 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 477 198 Naylor St, San Francisco, CA 94112, USA is geocoded now
# 478 55 Erie St, San Francisco, CA 94103, USA is geocoded now
# 479 620 Folsom St, San Francisco, CA 94107, USA is geocoded now
# 480 141 Treat St, San Francisco, CA 94103, USA is geocoded now
# 481 225 Pioche St, San Francisco, CA 94134, USA is geocoded now
# 482 98 Noe St, San Francisco, CA 94114, USA is geocoded now
# 483 3135 Washington St, San Francisco, CA 94115, USA is geocoded now
# 484 1800 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 485 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 486 72 Converse St, San Francisco, CA 94103, USA is geocoded now
# 487 135 Kissling St, San Francisco, CA 94103, USA is geocoded now
# 488 2099 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 489 852 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 490 2012 16th St, San Francisco, CA 94103, USA is geocoded now
# 491 188 Elliot St, San Francisco, CA 94134, USA is geocoded now
# 492 170 Madison St, San Francisco, CA 94134, USA is geocoded now
# 493 43 Cordova St, San Francisco, CA 94112, USA is geocoded now
# 494 1399 15th St, San Francisco, CA 94103, USA is geocoded now
# 495 386 Raymond Ave, San Francisco, CA 94134, USA is geocoded now
# 496 1320 Bryant St, San Francisco, CA 94103, USA is geocoded now
# 497 350 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 498 1390 Market St, San Francisco, CA 94102, USA is geocoded now
# 499 154 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 500 398 Hampshire St, San Francisco, CA 94110, USA is geocoded now
# 501 3150 Sacramento St, San Francisco, CA 94115, USA is geocoded now
# 502 808 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 503 808 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 504 4199 Mission St, San Francisco, CA 94112, USA is geocoded now
# 505 2024 Revere Ave, San Francisco, CA 94124, USA is geocoded now
# 506 620 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 507 5715 Mission St, San Francisco, CA 94112, USA is geocoded now
# 508 436 Murray St, San Francisco, CA 94110, USA is geocoded now
# 509 3222 Washington St, San Francisco, CA 94115, USA is geocoded now
# 510 599 S Van Ness Ave, San Francisco, CA 94110, USA is geocoded now
# 511 30 Camellia Ave, San Francisco, CA 94112, USA is geocoded now
# 512 1580 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 513 1544 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 514 151 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 515 1121 Athens St, San Francisco, CA 94112, USA is geocoded now
# 516 618 Hanover St, Daly City, CA 94014, USA is geocoded now
# 517 298 Grove St, San Francisco, CA 94102, USA is geocoded now
# 518 30 Grove St, San Francisco, CA 94102, USA is geocoded now
# 519 962 Teresita Blvd, San Francisco, CA 94127, USA is geocoded now
# 520 45 Chilton Ave, San Francisco, CA 94131, USA is geocoded now
# 521 2200 Market St, San Francisco, CA 94114, USA is geocoded now
# 522 25 Essex St, San Francisco, CA 94105, USA is geocoded now
# 523 98 Polk St, San Francisco, CA 94102, USA is geocoded now
# 524 473 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 525 318 Excelsior Ave, San Francisco, CA 94112, USA is geocoded now
# 526 1800 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 527 199 Acton St, Daly City, CA 94014, USA is geocoded now
# 528 1749 Harrison St, San Francisco, CA 94103, USA is geocoded now
# 529 207 Morse St, San Francisco, CA 94112, USA is geocoded now
# 530 3235 Clay St, San Francisco, CA 94115, USA is geocoded now
# 531 611 Folsom St, San Francisco, CA 94107, USA is geocoded now
# 532 91 Henry St, San Francisco, CA 94114, USA is geocoded now
# 533 554 Athens St, San Francisco, CA 94112, USA is geocoded now
# 534 650 Harrison St, San Francisco, CA 94107, USA is geocoded now
# 535 2 Mateo St, San Francisco, CA 94131, USA is geocoded now
# 536 131 Winchester St, Daly City, CA 94014, USA is geocoded now
# 537 25 Addison St, San Francisco, CA 94131, USA is geocoded now
# 538 666 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 539 553 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 540 685 Twin Peaks Blvd, San Francisco, CA 94114, USA is geocoded now
# 541 224 Pioche St, San Francisco, CA 94134, USA is geocoded now
# 542 2334 16th St, San Francisco, CA 94103, USA is geocoded now
# 543 65 Rousseau St, San Francisco, CA 94112, USA is geocoded now
# 544 4120 Mission St, San Francisco, CA 94112, USA is geocoded now
# 545 3301 Washington St, San Francisco, CA 94118, USA is geocoded now
# 546 1198 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 547 150 Duncan St, San Francisco, CA 94110, USA is geocoded now
# 548 176 Duncan St, San Francisco, CA 94110, USA is geocoded now
# 549 343 Frankfort St, Daly City, CA 94014, USA is geocoded now
# 550 965 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 551 4056 Mission St, San Francisco, CA 94112, USA is geocoded now
# 552 197 Rickard St, San Francisco, CA 94134, USA is geocoded now
# 553 792 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 554 1690 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 555 240 Lowell St, San Francisco, CA 94112, USA is geocoded now
# 556 959 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 557 56 Chilton Ave, San Francisco, CA 94131, USA is geocoded now
# 558 355 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 559 3040 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 560 1906 Baker St, San Francisco, CA 94115, USA is geocoded now
# 561 99 Shotwell St, San Francisco, CA 94103, USA is geocoded now
# 562 268 Alabama St, San Francisco, CA 94103, USA is geocoded now
# 563 1390 Market St, San Francisco, CA 94102, USA is geocoded now
# 564 27 Day St, San Francisco, CA 94110, USA is geocoded now
# 565 310 Ottilia St, Daly City, CA 94014, USA is geocoded now
# 566 1154 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 567 631 Hanover St, Daly City, CA 94014, USA is geocoded now
# 568 101 Boutwell St, San Francisco, CA 94124, USA is geocoded now
# 569 44 Agnon Ave, San Francisco, CA 94112, USA is geocoded now
# 570 68 Lippard Ave, San Francisco, CA 94131, USA is geocoded now
# 571 119A Steiner St, San Francisco, CA 94117, USA is geocoded now
# 572 799 Moscow St, San Francisco, CA 94112, USA is geocoded now
# 573 16 Risel Ave, Daly City, CA 94014, USA is geocoded now
# 574 900 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 575 1558 Dolores St, San Francisco, CA 94110, USA is geocoded now
# 576 166 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 577 3032 Divisadero St, San Francisco, CA 94123, USA is geocoded now
# 578 3010 Pacific Ave, San Francisco, CA 94115, USA is geocoded now
# 579 286 Raymond Ave, San Francisco, CA 94134, USA is geocoded now
# 580 1596 Dolores St, San Francisco, CA 94110, USA is geocoded now
# 581 31 Morse St, San Francisco, CA 94112, USA is geocoded now
# 582 210 29th St, San Francisco, CA 94131, USA is geocoded now
# 583 3273 Sacramento St, San Francisco, CA 94115, USA is geocoded now
# 584 319 Raymond Ave, San Francisco, CA 94134, USA is geocoded now
# 585 645 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 586 68 Potomac St, San Francisco, CA 94117, USA is geocoded now
# 587 189 13th St, San Francisco, CA 94103, USA is geocoded now
# 588 2201 Market St, San Francisco, CA 94114, USA is geocoded now
# 589 271 Surrey St, San Francisco, CA 94131, USA is geocoded now
# 590 2290 16th St, San Francisco, CA 94103, USA is geocoded now
# 591 450 10th St, San Francisco, CA 94103, USA is geocoded now
# 592 3121 Pierce St, San Francisco, CA 94115, USA is geocoded now
# 593 359 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 594 520 Arlington St, San Francisco, CA 94131, USA is geocoded now
# 595 444 Naples St, San Francisco, CA 94112, USA is geocoded now
# 596 50 Alberta St, San Francisco, CA 94134, USA is geocoded now
# 597 196 Lippard Ave, San Francisco, CA 94131, USA is geocoded now
# 598 2 Naylor St, San Francisco, CA 94112, USA is geocoded now
# 599 1398 15th St, San Francisco, CA 94103, USA is geocoded now
# 600 280 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 601 447 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 602 1245 Market St, San Francisco, CA 94102, USA is geocoded now
# 603 73 Noe St, San Francisco, CA 94114, USA is geocoded now
# 604 737 Burnett Ave, San Francisco, CA 94131, USA is geocoded now
# 605 100 Larkin St, San Francisco, CA 94102, USA is geocoded now
# 606 151 Lippard Ave, San Francisco, CA 94131, USA is geocoded now
# 607 150 Hampshire St, San Francisco, CA 94103, USA is geocoded now
# 608 99 Avalon Ave, San Francisco, CA 94112, USA is geocoded now
# 609 2636 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 610 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 611 1099 Ellsworth St, San Francisco, CA 94112, USA is geocoded now
# 612 119 Utah St, San Francisco, CA 94103, USA is geocoded now
# 613 357 Alemany Blvd, San Francisco, CA 94110, USA is geocoded now
# 614 399 Golden Gate Ave, San Francisco, CA 94102, USA is geocoded now
# 615 125 Accacia St, Daly City, CA 94014, USA is geocoded now
# 616 730 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 617 170 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 618 2760 Divisadero St, San Francisco, CA 94123, USA is geocoded now
# 619 42 Walter St, San Francisco, CA 94114, USA is geocoded now
# 620 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 621 3160 Clay St, San Francisco, CA 94115, USA is geocoded now
# 622 1117 Cayuga Ave, San Francisco, CA 94112, USA is geocoded now
# 623 148 Oriente St, Daly City, CA 94014, USA is geocoded now
# 624 50 28th St, San Francisco, CA 94110, USA is geocoded now
# 625 4963 Mission St, San Francisco, CA 94112, USA is geocoded now
# 626 2685 Diamond St, San Francisco, CA 94131, USA is geocoded now
# 627 302 Potrero Ave, San Francisco, CA 94110, USA is geocoded now
# 628 1919 Baker St, San Francisco, CA 94115, USA is geocoded now
# 629 808 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 630 237 Oxford St, San Francisco, CA 94134, USA is geocoded now
# 631 215 Harvard St, San Francisco, CA 94134, USA is geocoded now
# 632 801 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 633 1063 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 634 25 Belcher St, San Francisco, CA 94114, USA is geocoded now
# 635 2925 Geneva Ave, Daly City, CA 94014, USA is geocoded now
# 636 146 London St, San Francisco, CA 94112, USA is geocoded now
# 637 227 Bemis St, San Francisco, CA 94131, USA is geocoded now
# 638 125 Schwerin St, San Francisco, CA 94134, USA is geocoded now
# 639 706 Acton St, Daly City, CA 94014, USA is geocoded now
# 640 145 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 641 498 Bellevue Ave, Daly City, CA 94014, USA is geocoded now
# 642 305 Ottilia St, Daly City, CA 94014, USA is geocoded now
# 643 231 Seneca Ave, San Francisco, CA 94112, USA is geocoded now
# 644 845 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 645 121 Accacia St, Daly City, CA 94014, USA is geocoded now
# 646 5 Moffitt St, San Francisco, CA 94131, USA is geocoded now
# 647 1699 Howard St, San Francisco, CA 94103, USA is geocoded now
# 648 361 Frankfort St, Daly City, CA 94014, USA is geocoded now
# 649 327 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 650 1949 Silver Ave, San Francisco, CA 94124, USA is geocoded now
# 651 19 Waterville St, San Francisco, CA 94124, USA is geocoded now
# 652 1257 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 653 526 Naples St, San Francisco, CA 94112, USA is geocoded now
# 654 80 Charter Oak Ave, San Francisco, CA 94124, USA is geocoded now
# 655 198 Florida St, San Francisco, CA 94103, USA is geocoded now
# 656 1618 Guerrero St, San Francisco, CA 94110, USA is geocoded now
# 657 420 Leland Ave, San Francisco, CA 94134, USA is geocoded now
# 658 2736 16th St, San Francisco, CA 94103, USA is geocoded now
# 659 10 29th St, San Francisco, CA 94110, USA is geocoded now
# 660 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 661 155 Duncan St, San Francisco, CA 94110, USA is geocoded now
# 662 54 Valley St, San Francisco, CA 94110, USA is geocoded now
# 663 719 Sweeny St, San Francisco, CA 94134, USA is geocoded now
# 664 1489 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 665 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 666 1770 15th St, San Francisco, CA 94103, USA is geocoded now
# 667 425 2nd St, San Francisco, CA 94107, USA is geocoded now
# 668 617 San Jose Avenue, San Francisco, CA 94110, USA is geocoded now
# 669 631 Hanover St, Daly City, CA 94014, USA is geocoded now
# 670 731 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 671 616 Rolph St, San Francisco, CA 94112, USA is geocoded now
# 672 370 Valencia St, San Francisco, CA 94103, USA is geocoded now
# 673 263 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 674 322 Presidio Ave, San Francisco, CA 94115, USA is geocoded now
# 675 140 Cuvier St, San Francisco, CA 94112, USA is geocoded now
# 676 2615 Scott St, San Francisco, CA 94123, USA is geocoded now
# 677 355 Frankfort St, Daly City, CA 94014, USA is geocoded now
# 678 359 Dore St, San Francisco, CA 94103, USA is geocoded now
# 679 3093 Sacramento St, San Francisco, CA 94115, USA is geocoded now
# 680 124 Oriente St, Daly City, CA 94014, USA is geocoded now
# 681 196 Elliot St, San Francisco, CA 94134, USA is geocoded now
# 682 771 Sweeny St, San Francisco, CA 94134, USA is geocoded now
# 683 341 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 684 1299 San Jose Avenue, San Francisco, CA 94112, USA is geocoded now
# 685 359 Hermann St, San Francisco, CA 94117, USA is geocoded now
# 686 400 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 687 564 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 688 81 Albion St, San Francisco, CA 94103, USA is geocoded now
# 689 701 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 690 1951 Lyon St, San Francisco, CA 94115, USA is geocoded now
# 691 130 Joost Ave, San Francisco, CA 94131, USA is geocoded now
# 692 75 W View Ave, San Francisco, CA 94134, USA is geocoded now
# 693 459 Bellevue Ave, Daly City, CA 94014, USA is geocoded now
# 694 121 Harvard St, San Francisco, CA 94134, USA is geocoded now
# 695 257 Crescent Ave, San Francisco, CA 94110, USA is geocoded now
# 696 140 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 697 71 Lyell St, San Francisco, CA 94112, USA is geocoded now
# 698 484 Chenery St, San Francisco, CA 94131, USA is geocoded now
# 699 2635 Green St, San Francisco, CA 94123, USA is geocoded now
# 700 246 Richland Ave, San Francisco, CA 94110, USA is geocoded now
# 701 869 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 702 1851 15th St, San Francisco, CA 94103, USA is geocoded now
# 703 107 28th St, San Francisco, CA 94131, USA is geocoded now
# 704 129 Steiner St, San Francisco, CA 94117, USA is geocoded now
# 705 1675 Howard St, San Francisco, CA 94103, USA is geocoded now
# 706 412 Valencia St, San Francisco, CA 94103, USA is geocoded now
# 707 302 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 708 1201 Naples St, San Francisco, CA 94112, USA is geocoded now
# 709 2000 Folsom St, San Francisco, CA 94110, USA is geocoded now
# 710 2672 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 711 431 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 712 92 Charter Oak Ave, San Francisco, CA 94124, USA is geocoded now
# 713 247 Madrid St, San Francisco, CA 94112, USA is geocoded now
# 714 974 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 715 110 Steiner St, San Francisco, CA 94117, USA is geocoded now
# 716 1253 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 717 165 Burnside Ave, San Francisco, CA 94131, USA is geocoded now
# 718 3169 Clay St, San Francisco, CA 94115, USA is geocoded now
# 719 598 Harrison St, San Francisco, CA 94105, USA is geocoded now
# 720 528 Folsom St, San Francisco, CA 94105, USA is geocoded now
# 721 91 Charter Oak Ave, San Francisco, CA 94124, USA is geocoded now
# 722 145 Oxford St, San Francisco, CA 94134, USA is geocoded now
# 723 1399 15th St, San Francisco, CA 94103, USA is geocoded now
# 724 270 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 725 57 Morse St, San Francisco, CA 94112, USA is geocoded now
# 726 19 Waterville St, San Francisco, CA 94124, USA is geocoded now
# 727 152 Helena St, San Francisco, CA 94124, USA is geocoded now
# 728 78 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 729 1218 Market St, San Francisco, CA 94102, USA is geocoded now
# 730 2134 Market St, San Francisco, CA 94114, USA is geocoded now
# ...
# 1952 1919 Baker St, San Francisco, CA 94115, USA is geocoded now
# 1953 400 Pioche St, San Francisco, CA 94134, USA is geocoded now
# 1954 3800 Sanchez St, San Francisco, CA 94114, USA is geocoded now
# 1955 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 1956 469 11th St, San Francisco, CA 94103, USA is geocoded now
# 1957 10 Agnon Ave, San Francisco, CA 94112, USA is geocoded now
# 1958 1163 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 1959 45 29th St, San Francisco, CA 94110, USA is geocoded now
# 1960 325 Harvard St, San Francisco, CA 94134, USA is geocoded now
# 1961 112 Avalon Ave, San Francisco, CA 94112, USA is geocoded now
# 1962 869 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 1963 499 Otsego Ave, San Francisco, CA 94112, USA is geocoded now
# 1964 2170 Revere Ave, San Francisco, CA 94124, USA is geocoded now
# 1965 3095 Pacific Ave, San Francisco, CA 94115, USA is geocoded now
# 1966 167 Curtis St, San Francisco, CA 94112, USA is geocoded now
# 1967 207 Oriente St, Daly City, CA 94014, USA is geocoded now
# 1968 2030 Harrison St, San Francisco, CA 94110, USA is geocoded now
# 1969 212 Cambridge St, San Francisco, CA 94134, USA is geocoded now
# 1970 2700 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 1971 1257 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 1972 74 Arnold Ave, San Francisco, CA 94110, USA is geocoded now
# 1973 3170 Sacramento St, San Francisco, CA 94115, USA is geocoded now
# 1974 869 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 1975 1349 San Jose Avenue, San Francisco, CA 94131, USA is geocoded now
# 1976 405 Allison St, San Francisco, CA 94112, USA is geocoded now
# 1977 1991 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 1978 598 Harrison St, San Francisco, CA 94105, USA is geocoded now
# 1979 342 Elliot St, San Francisco, CA 94134, USA is geocoded now
# 1980 2010 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 1981 322 Oliver St, Daly City, CA 94014, USA is geocoded now
# 1982 170 Cora St, San Francisco, CA 94134, USA is geocoded now
# 1983 551 Templeton Ave, Daly City, CA 94014, USA is geocoded now
# 1984 170 S Van Ness Ave, San Francisco, CA 94103, USA is geocoded now
# 1985 422 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 1986 162 Oriente St, Daly City, CA 94014, USA is geocoded now
# 1987 460 McAllister St, San Francisco, CA 94102, USA is geocoded now
# 1988 310 Alemany Blvd, San Francisco, CA 94110, USA is geocoded now
# 1989 450 10th St, San Francisco, CA 94103, USA is geocoded now
# 1990 Twin Peaks Blvd, San Francisco, CA 94114, USA is geocoded now
# 1991 11 Navajo Ave, San Francisco, CA 94112, USA is geocoded now
# 1992 55 Trumbull St, San Francisco, CA 94112, USA is geocoded now
# 1993 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 1994 777 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 1995 531 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 1996 35 Fell St, San Francisco, CA 94102, USA is geocoded now
# 1997 30 Grove St, San Francisco, CA 94102, USA is geocoded now
# 1998 221 Accacia St, Daly City, CA 94014, USA is geocoded now
# 1999 3068 California St, San Francisco, CA 94115, USA is geocoded now
# 2000 808 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 2001 737 Paris St, San Francisco, CA 94112, USA is geocoded now
# 2002 681 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 2003 3125 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 2004 243 Rolph St, San Francisco, CA 94112, USA is geocoded now
# 2005 3120 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 2006 3048 Geneva Ave, Daly City, CA 94014, USA is geocoded now
# 2007 2780 Vallejo St, San Francisco, CA 94123, USA is geocoded now
# 2008 200 Larkin St, San Francisco, CA 94102, USA is geocoded now
# 2009 9 Tingley St, San Francisco, CA 94112, USA is geocoded now
# 2010 195 Lowell St, San Francisco, CA 94112, USA is geocoded now
# 2011 555 9th St, San Francisco, CA 94103, USA is geocoded now
# 2012 3048 Geneva Ave, Daly City, CA 94014, USA is geocoded now
# 2013 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 2014 4987 Mission St, San Francisco, CA 94112, USA is geocoded now
# 2015 208 Accacia St, Daly City, CA 94014, USA is geocoded now
# 2016 310 Alemany Blvd, San Francisco, CA 94110, USA is geocoded now
# 2017 79 Waterville St, San Francisco, CA 94124, USA is geocoded now
# 2018 68 Topeka Ave, San Francisco, CA 94124, USA is geocoded now
# 2019 1098 San Jose Avenue, San Francisco, CA 94131, USA is geocoded now
# 2020 206 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 2021 106 Presidio Ave, San Francisco, CA 94115, USA is geocoded now
# 2022 322 Teddy Ave, San Francisco, CA 94134, USA is geocoded now
# 2023 411 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 2024 67 Maddux Ave, San Francisco, CA 94124, USA is geocoded now
# 2025 654 Twin Peaks Blvd, San Francisco, CA 94114, USA is geocoded now
# 2026 140 Accacia St, Daly City, CA 94014, USA is geocoded now
# 2027 311 Gambier St, San Francisco, CA 94134, USA is geocoded now
# 2028 742 Lisbon St, San Francisco, CA 94112, USA is geocoded now
# 2029 150 Hayes St, San Francisco, CA 94102, USA is geocoded now
# 2030 554 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 2031 114 29th St, San Francisco, CA 94110, USA is geocoded now
# 2032 480 Raymond Ave, San Francisco, CA 94134, USA is geocoded now
# 2033 1184 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 2034 2923 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 2035 2186 Market St, San Francisco, CA 94114, USA is geocoded now
# 2036 555 Moscow St, San Francisco, CA 94112, USA is geocoded now
# 2037 1340 Bryant St, San Francisco, CA 94103, USA is geocoded now
# 2038 308 Oxford St, San Francisco, CA 94134, USA is geocoded now
# 2039 418 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 2040  B Mission St, San Francisco, CA 94112, USA is geocoded now
# 2041 2200 Market St, San Francisco, CA 94114, USA is geocoded now
# 2042 Polk St, San Francisco, CA 94102, USA is geocoded now
# 2043 300 Hampshire St, San Francisco, CA 94110, USA is geocoded now
# 2044 149 Beacon St, San Francisco, CA 94131, USA is geocoded now
# 2045 44 Santa Fe Ave, San Francisco, CA 94124, USA is geocoded now
# 2046 205 Topeka Ave, San Francisco, CA 94124, USA is geocoded now
# 2047 799 14th St, San Francisco, CA 94114, USA is geocoded now
# 2048 1340 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 2049 221 Cordova St, San Francisco, CA 94112, USA is geocoded now
# 2050 92 Charter Oak Ave, San Francisco, CA 94124, USA is geocoded now
# 2051 100 Larkin St, San Francisco, CA 94102, USA is geocoded now
# 2052 279 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 2053 1884 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 2054 30 Fillmore St, San Francisco, CA 94117, USA is geocoded now
# 2055 80 Everson St, San Francisco, CA 94131, USA is geocoded now
# 2056 2485 Union St, San Francisco, CA 94123, USA is geocoded now
# 2057 900 Moscow St, San Francisco, CA 94112, USA is geocoded now
# 2058 429 Rolph St, San Francisco, CA 94112, USA is geocoded now
# 2059 51 Ramona Ave, San Francisco, CA 94103, USA is geocoded now
# 2060 1590 Bryant St, San Francisco, CA 94103, USA is geocoded now
# 2061 1695 Mission St, San Francisco, CA 94103, USA is geocoded now
# 2062 2975 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 2063 269 Arleta Ave, San Francisco, CA 94134, USA is geocoded now
# 2064 661 Twin Peaks Blvd, San Francisco, CA 94114, USA is geocoded now
# 2065 635 San Jose Avenue, San Francisco, CA 94110, USA is geocoded now
# 2066 Plum St, San Francisco, CA 94103, USA is geocoded now
# 2067 44 Santa Fe Ave, San Francisco, CA 94124, USA is geocoded now
# 2068 40 Lippard Ave, San Francisco, CA 94131, USA is geocoded now
# 2069 431 Murray St, San Francisco, CA 94110, USA is geocoded now
# 2070 516 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 2071 310 Alemany Blvd, San Francisco, CA 94110, USA is geocoded now
# 2072 1835 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 2073 198 Fulton St, San Francisco, CA 94102, USA is geocoded now
# 2074 701 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 2075 143 Winchester St, Daly City, CA 94014, USA is geocoded now
# 2076 380 10th St, San Francisco, CA 94103, USA is geocoded now
# 2077 1 Bemis St, San Francisco, CA 94131, USA is geocoded now
# 2078 2124 15th St, San Francisco, CA 94114, USA is geocoded now
# 2079 650 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 2080 375 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 2081 125 Peru Ave, San Francisco, CA 94112, USA is geocoded now
# 2082 116 Miguel St, San Francisco, CA 94131, USA is geocoded now
# 2083 3018 Washington St, San Francisco, CA 94115, USA is geocoded now
# 2084 2945 Scott St, San Francisco, CA 94123, USA is geocoded now
# 2085 1479 Guerrero St, San Francisco, CA 94110, USA is geocoded now
# 2086 2727 Pierce St, San Francisco, CA 94123, USA is geocoded now
# 2087 148 Noe St, San Francisco, CA 94114, USA is geocoded now
# 2088 3264 Mission St, San Francisco, CA 94110, USA is geocoded now
# 2089 498 Athens St, San Francisco, CA 94112, USA is geocoded now
# 2090 45 Scotia Ave, San Francisco, CA 94124, USA is geocoded now
# 2091 651 Morse St, San Francisco, CA 94112, USA is geocoded now
# 2092 3053 California St, San Francisco, CA 94115, USA is geocoded now
# 2093 51 Duncan St, San Francisco, CA 94110, USA is geocoded now
# 2094 114 Crescent Ave, San Francisco, CA 94110, USA is geocoded now
# 2095 818 Persia Ave, San Francisco, CA 94112, USA is geocoded now
# 2096 836 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 2097 1617 13th St, San Francisco, CA 94103, USA is geocoded now
# 2098 801 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 2099 478 Bosworth St, San Francisco, CA 94112, USA is geocoded now
# 2100 181 Bertita St, San Francisco, CA 94112, USA is geocoded now
# 2101 210 Utah St, San Francisco, CA 94103, USA is geocoded now
# 2102 621 Harrison St, San Francisco, CA 94107, USA is geocoded now
# 2103 1250 Naples St, San Francisco, CA 94112, USA is geocoded now
# 2104 578 Athens St, San Francisco, CA 94112, USA is geocoded now
# 2105 330 11th St, San Francisco, CA 94103, USA is geocoded now
# 2106 937 Silver Ave, San Francisco, CA 94134, USA is geocoded now
# 2107 564 Duboce Ave, San Francisco, CA 94117, USA is geocoded now
# 2108 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 2109 210 Edinburgh St, San Francisco, CA 94112, USA is geocoded now
# 2110 1173 Munich St, San Francisco, CA 94112, USA is geocoded now
# 2111 869 Schwerin St, Daly City, CA 94014, USA is geocoded now
# 2112 625 Bayshore Blvd, San Francisco, CA 94124, USA is geocoded now
# 2113 450 10th St, San Francisco, CA 94103, USA is geocoded now
# 2114 338 Guerrero St, San Francisco, CA 94103, USA is geocoded now
# 2115 59 Sheridan St, San Francisco, CA 94103, USA is geocoded now
# 2116 562 Vienna St, San Francisco, CA 94112, USA is geocoded now
# 2117 12 Shotwell St, San Francisco, CA 94103, USA is geocoded now
# 2118 341 Bellevue Ave, Daly City, CA 94014, USA is geocoded now
# 2119 186 Oriente St, Daly City, CA 94014, USA is geocoded now
# 2120 1415 Folsom St, San Francisco, CA 94103, USA is geocoded now
# 2121 2013 16th St, San Francisco, CA 94103, USA is geocoded now
# 2122 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 2123 530 Folsom St, San Francisco, CA 94105, USA is geocoded now
# 2124 3065 Jackson St, San Francisco, CA 94115, USA is geocoded now
# 2125 2300 16th St, San Francisco, CA 94103, USA is geocoded now
# 2126 1844 Market St, San Francisco, CA 94102, USA is geocoded now
# 2127 359 Silver Ave, San Francisco, CA 94112, USA is geocoded now
# 2128 571 Mangels Ave, San Francisco, CA 94127, USA is geocoded now
# 2129 50 Fulton St, San Francisco, CA 94102, USA is geocoded now
# 2130 568 Athens St, San Francisco, CA 94112, USA is geocoded now
# 2131 280 Surrey St, San Francisco, CA 94131, USA is geocoded now
# 2132 4100 Mission St, San Francisco, CA 94112, USA is geocoded now
# 2133 346 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 2134 100 Rousseau St, San Francisco, CA 94112, USA is geocoded now
# 2135 70 13th St, San Francisco, CA 94103, USA is geocoded now
# 2136 594 Alemany Blvd, San Francisco, CA 94110, USA is geocoded now
# 2137 15 Italy Ave, San Francisco, CA 94112, USA is geocoded now
# 2138 353 Melrose Ave, San Francisco, CA 94127, USA is geocoded now
# 2139 120 Accacia St, Daly City, CA 94014, USA is geocoded now
# 2140 685 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 2141 243 Duboce Ave, San Francisco, CA 94103, USA is geocoded now
# 2142 60 Maddux Ave, San Francisco, CA 94124, USA is geocoded now
# 2143 49 Bemis St, San Francisco, CA 94131, USA is geocoded now
# 2144 999 Brannan St, San Francisco, CA 94103, USA is geocoded now
# 2145 17 Maynard St, San Francisco, CA 94112, USA is geocoded now
# 2146 1015 Bosworth St, San Francisco, CA 94131, USA is geocoded now
# 2147 55 Erie St, San Francisco, CA 94103, USA is geocoded now
# 2148 112 Schwerin St, San Francisco, CA 94134, USA is geocoded now
# 2149 199 York St, San Francisco, CA 94103, USA is geocoded now
# 2150 2133 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 2151 121 Accacia St, Daly City, CA 94014, USA is geocoded now
# 2152 227 Presidio Ave, San Francisco, CA 94115, USA is geocoded now
# 2153 5059 Mission St, San Francisco, CA 94112, USA is geocoded now
# 2154 3201 Washington St, San Francisco, CA 94115, USA is geocoded now
# 2155 Earl Warren Building, 350 McAllister St, San Francisco, CA 94102, USA is geocoded now
# 2156 998 Twin Peaks Blvd, San Francisco, CA 94131, USA is geocoded now
# 2157 509 Naples St, San Francisco, CA 94112, USA is geocoded now
# 2158 108 Schwerin St, San Francisco, CA 94134, USA is geocoded now
# 2159 698 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 2160 2524 Union St, San Francisco, CA 94123, USA is geocoded now
# 2161 151 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 2162 716 San Jose Avenue, San Francisco, CA 94110, USA is geocoded now
# 2163 150 Van Ness Ave, San Francisco, CA 94102, USA is geocoded now
# 2164 128 Elmira St, San Francisco, CA 94124, USA is geocoded now
# 2165 2499 Lyon St, San Francisco, CA 94115, USA is geocoded now
# 2166 1676 13th St, San Francisco, CA 94103, USA is geocoded now
# 2167 75 Everson St, San Francisco, CA 94131, USA is geocoded now
# 2168 293 Surrey St, San Francisco, CA 94131, USA is geocoded now
# 2169 875 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 2170 337 Hermann St, San Francisco, CA 94117, USA is geocoded now
# 2171 2050 Alemany Blvd, San Francisco, CA 94112, USA is geocoded now
# 2172 66 14th St, San Francisco, CA 94103, USA is geocoded now
# 2173 448 Laidley St, San Francisco, CA 94131, USA is geocoded now
# 2174 98 Elliot St, San Francisco, CA 94134, USA is geocoded now
# 2175 Earl Warren Building, 350 McAllister St, San Francisco, CA 94102, USA is geocoded now
# 2176 70 Van Buren St, San Francisco, CA 94131, USA is geocoded now
# 2177 175 Potrero Ave, San Francisco, CA 94103, USA is geocoded now
# 2178 1446 Market St, San Francisco, CA 94102, USA is geocoded now
# 2179 4364 Mission St, San Francisco, CA 94112, USA is geocoded now
# 2180 299 Shotwell St, San Francisco, CA 94110, USA is geocoded now
# 2181 120 Topeka Ave, San Francisco, CA 94124, USA is geocoded now
# 2182 330 10th St, San Francisco, CA 94103, USA is geocoded now
# 2183 443 Bosworth St, San Francisco, CA 94112, USA is geocoded now
# 2184 266 Hayes St, San Francisco, CA 94102, USA is geocoded now
# 2185 162 Accacia St, Daly City, CA 94014, USA is geocoded now
# 2186 72 Topeka Ave, San Francisco, CA 94124, USA is geocoded now
# 2187 330 Oliver St, Daly City, CA 94014, USA is geocoded now
# 2188 94 W View Ave, San Francisco, CA 94134, USA is geocoded now
# 2189 1599 Geneva Ave, San Francisco, CA 94112, USA is geocoded now
# 2190 499 Treat Ave, San Francisco, CA 94110, USA is geocoded now

# %%
employee_addresses_gecoded.head()
# Out:
#                                             response   latitude   longitude
# 0  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.727642 -122.427315
# 1  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.704180 -122.415820
# 2  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.767930 -122.415100
# 3  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.729660 -122.419720
# 4  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.736240 -122.431320

# %%
employee_addresses_gecoded.to_csv("employee_addresses_gecoded.csv")

# %%
employee_addresses = pd.concat([employee_addresses, employee_addresses_gecoded], axis=1)
employee_addresses.head()
# Out:
#                                           address  employee_id  \
# 0   98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1        237 Accacia St, Daly City, CA 94014, USA         2081
# 2    1835 Folsom St, San Francisco, CA 94103, USA          178
# 3  170 Cambridge St, San Francisco, CA 94134, USA           50
# 4     16 Roanoke St, San Francisco, CA 94131, USA         1863
#
#                                             response   latitude   longitude
# 0  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.727642 -122.427315
# 1  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.704180 -122.415820
# 2  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.767930 -122.415100
# 3  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.729660 -122.419720
# 4  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.736240 -122.431320

# %% [markdown]
# ### Save data as csv files and then read them again to run them easily from here

# %%
employee_addresses.to_csv("employee_data.csv", index=False)
bus_stops.to_csv("bus_stops_data.csv", index=False)

# %%
employee_data  = pd.read_csv("employee_data.csv")
bus_stops_data = pd.read_csv("bus_stops_data.csv")

# %%
employee_data.head()
# Out:
#                                           address  employee_id  \
# 0   98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1        237 Accacia St, Daly City, CA 94014, USA         2081
# 2    1835 Folsom St, San Francisco, CA 94103, USA          178
# 3  170 Cambridge St, San Francisco, CA 94134, USA           50
# 4     16 Roanoke St, San Francisco, CA 94131, USA         1863
#
#                                             response   latitude   longitude
# 0  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.727642 -122.427315
# 1  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.704180 -122.415820
# 2  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.767930 -122.415100
# 3  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.729660 -122.419720
# 4  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.736240 -122.431320

# %%
employee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191 entries, 0 to 2190
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   address      2191 non-null   object
#  1   employee_id  2191 non-null   int64
#  2   response     2191 non-null   object
#  3   latitude     2191 non-null   float64
#  4   longitude    2191 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 85.7+ KB

# %%
employee_data.describe()
# Out:
#        employee_id     latitude    longitude
# count  2191.000000  2191.000000  2191.000000
# mean   1096.000000    37.744349  -122.425281
# std     632.631541     0.026933     0.013984
# min       1.000000    37.702862  -122.451970
# 25%     548.500000    37.721080  -122.435535
# 50%    1096.000000    37.736104  -122.425570
# 75%    1643.500000    37.767920  -122.414620
# max    2191.000000    37.798920  -122.389980

# %%
bus_stops_data.head()
# Out:
#    Street_One         Street_Two                        address  \
# 0  MISSION ST          ITALY AVE          MISSION ST, ITALY AVE
# 1  MISSION ST  NEW MONTGOMERY ST  MISSION ST, NEW MONTGOMERY ST
# 2  MISSION ST             1ST ST             MISSION ST, 1ST ST
# 3  MISSION ST            20TH ST            MISSION ST, 20TH ST
# 4  MISSION ST         FREMONT ST         MISSION ST, FREMONT ST
#
#                                             response  latitude  longitude
# 0  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.71675 -122.43594
# 1  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78747 -122.40052
# 2  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.77867 -122.41160
# 3  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.75887 -122.41513
# 4  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78987 -122.39595

# %%
bus_stops_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Street_One  119 non-null    object
#  1   Street_Two  119 non-null    object
#  2   address     119 non-null    object
#  3   response    119 non-null    object
#  4   latitude    119 non-null    float64
#  5   longitude   119 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 5.7+ KB

# %%
bus_stops_data.describe()
# Out:
#          latitude   longitude
# count  119.000000  119.000000
# mean    37.747559 -122.423357
# std      0.026985    0.016045
# min     37.708540 -122.452550
# 25%     37.723355 -122.436085
# 50%     37.743990 -122.420060
# 75%     37.772950 -122.412810
# max     37.793550 -122.389460

# %%
# Extraxt location data 
employee_data_location = employee_data[['latitude', 'longitude']]
bus_stops_data_location = bus_stops_data[['latitude', 'longitude']]

# %%
class Clusterer:
    
    def __init__(self, employee_data, bus_stops_data):
        self.employee_data = employee_data
        self.bus_stops_data = bus_stops_data
    
    
    def apply_kmeans_clustering(self, n_clusters):
        '''
        Parameters:
            n_clusters (int): the number of centroids
        Returns:
            labels (nparray): the labels for each datapoint to which group it belongs
            centers (nparray): the centers of the clusters 
            score (float): the silhouette score of the clstering algorithm 
        '''
        
        kmeans = KMeans(n_clusters=n_clusters, random_state=0)
        km_labels = kmeans.fit_predict(self.employee_data[['latitude', 'longitude']])
        km_centers = kmeans.cluster_centers_
        km_score =  silhouette_score(self.employee_data[['latitude', 'longitude']], km_labels)

        return km_labels, km_centers, km_score

    
    def apply_hclustering(self, n_clusters, linkage, affinity):
        '''
        Parameters:
            n_clusters (int): the number of centroids
            linkage (str): linkage method; 'complete', 'average', 'ward'
        Returns:
            labels (nparray): the labels for each datapoint to which group it belongs
            centers (nparray): the centers of the clusters 
            score (float): the silhouette score of the clstering algorithm 
        '''
        
        hclust = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage, affinity=affinity)
        hclust_labels = hclust.fit_predict(self.employee_data[['latitude', 'longitude']])
        
        # get centroid of each cluster 
        clf = NearestCentroid()
        clf.fit(self.employee_data[['latitude', 'longitude']], hclust_labels)
        hclust_centers = clf.centroids_
        
        hclust_score =  silhouette_score(self.employee_data[['latitude', 'longitude']], hclust_labels)

        return hclust_labels, hclust_centers, hclust_score
    
    
    def apply_gmm(self, n_clusters):
        '''
        Parameters:
            n_clusters (int): the number of centroids
        Returns:
            labels (nparray): the labels for each datapoint to which group it belongs
            centers (nparray): the centers of the clusters 
            score (float): the silhouette score of the clstering algorithm 
        '''
        gmm_clusterer = GaussianMixture(n_components=n_clusters, random_state=0)
        gmm_labels = gmm_clusterer.fit_predict(self.employee_data[['latitude', 'longitude']])
        
        # get centroids 
        X = self.employee_data[['latitude', 'longitude']].to_numpy()
        gmm_centers = np.empty(shape=(gmm_clusterer.n_components, X.shape[1]))
        for i in range(gmm_clusterer.n_components):
            density = multivariate_normal(cov=gmm_clusterer.covariances_[i], mean=gmm_clusterer.means_[i]).logpdf(X)
            gmm_centers[i, :] = X[np.argmax(density)]
        
        gmm_score = silhouette_score(self.employee_data[['latitude', 'longitude']], gmm_labels)
        
        return gmm_labels, gmm_centers, gmm_score
        
    def plot_original_data(self):
        fig = plt.figure(figsize=(12,8))

        plt.scatter(x=self.employee_data['latitude'], y=self.employee_data['longitude'], label='Employee addresses')
        plt.scatter(x=self.bus_stops_data['latitude'], y=self.bus_stops_data['longitude'], label='Bus Stops')

        plt.xlabel("latitude")
        plt.ylabel("longitude")
        plt.title("Employees addresses and bus stops")
        plt.legend()
        
        
    def plot_map_box_original_data(self):
        mapbox_access_token = open(".mapbox_token").read()

        fig = go.Figure()

        fig.add_trace(go.Scattermapbox(
            lat=self.employee_data['latitude'],
            lon=self.employee_data['longitude'],
            mode='markers',
            name="Employee Addresses",
            marker=go.scattermapbox.Marker(
                size=10,
                color='rgb(30,144,255)',
            ),
            text=self.employee_data['employee_id'],
            hoverinfo='text'
        ))

        fig.add_trace(go.Scattermapbox(
            lat=self.bus_stops_data['latitude'],
            lon=self.bus_stops_data['longitude'],
            mode='markers',
            name="Bus Stops",
            marker=go.scattermapbox.Marker(
                size=10,
                color='rgb(255,140,0)',
            ),
            text=self.bus_stops_data['Street_Two'],
            hoverinfo='text',
        ))

        fig.update_layout(
            title='Employee addresses and bus stops locations',
            autosize=True,
            hovermode='closest',
            showlegend=True,
            mapbox=dict(
                accesstoken=mapbox_access_token,
                bearing=0,
                center=dict(
                    lat=37.77,
                    lon=-122.5
                ),
                pitch=0,
                zoom=10,
                style='light'
            ),
        )

        fig.show()

    
    def plot_clusters(self, labels, centers):
        
        fig = plt.figure(figsize=(12,6))

        plt.scatter(x=self.employee_data['latitude'], y=self.employee_data['longitude'], c=labels, cmap='Set1')
        plt.scatter(x=centers['latitude'], y=centers['longitude'], c='black')
        
        plt.xlabel("latitude")
        plt.ylabel("longitude")
        plt.title("Employees addresses clusters with centroids")
        

    def plot_map_box_clusters(self, labels, centers):
        mapbox_access_token = open(".mapbox_token").read()

        fig = go.Figure()

        fig.add_trace(go.Scattermapbox(
            lat=self.employee_data['latitude'],
            lon=self.employee_data['longitude'],
            mode='markers',
            name="Employee Addresses",
            marker=go.scattermapbox.Marker(
                size=7,
                color=labels,
            ),
            text=self.employee_data['employee_id'],
            hoverinfo='text'
        ))
        
        fig.add_trace(go.Scattermapbox(
            lat=centers['latitude'],
            lon=centers['longitude'],
            mode='markers',
            name="clusters centers",
            marker=go.scattermapbox.Marker(
                size=10,
                color='rgb(0, 0, 0)',
            ),
        ))


        fig.update_layout(
            title='Employee addresses clusters',
            autosize=True,
            hovermode='closest',
            showlegend=False,
            mapbox=dict(
                accesstoken=mapbox_access_token,
                bearing=0,
                center=dict(
                    lat=37.77,
                    lon=-122.5
                ),
                pitch=0,
                zoom=10,
                style='light'
            ),
        )

        fig.show()
        
    def plot_best_stops(self, labels, centers, best_stops):
                
        fig = plt.figure(figsize=(12,6))

        plt.scatter(x=self.employee_data['latitude'], y=self.employee_data['longitude'], c=labels, cmap='Set1')
        plt.scatter(x=centers['latitude'], y=centers['longitude'], c='black')
        plt.scatter(x=best_stops['latitude'], y=best_stops['longitude'], c='green', label='Best Stops')
        
        plt.xlabel("latitude")
        plt.ylabel("longitude")
        plt.title("Employees addresses clusters with centroids")
        plt.legend()
        
        
    def plot_map_box_best_stops(self, labels, centers, best_stops):
        mapbox_access_token = open(".mapbox_token").read()

        fig = go.Figure()

        fig.add_trace(go.Scattermapbox(
            lat=self.employee_data['latitude'],
            lon=self.employee_data['longitude'],
            mode='markers',
            name="",
            marker=go.scattermapbox.Marker(
                size=7,
                color=labels,
            ),
            text=employee_data['employee_id'],
            hoverinfo='text'
        ))

        fig.add_trace(go.Scattermapbox(
            lat=self.bus_stops_data['latitude'],
            lon=self.bus_stops_data['longitude'],
            mode='markers',
            name="Bus Stops",
            marker=go.scattermapbox.Marker(
                size=7,
                color='rgb(0, 200, 255)',
            ),
            text=bus_stops_data['Street_Two'],
            hoverinfo='text',
        ))

        fig.add_trace(go.Scattermapbox(
            lat=centers['latitude'],
            lon=centers['longitude'],
            mode='markers',
            name="cluster center",
            marker=go.scattermapbox.Marker(
                size=10,
                color='rgb(0, 0, 0)',
            ),
        ))

        fig.add_trace(go.Scattermapbox(
            lat=best_stops['latitude'],
            lon=best_stops['longitude'],
            mode='markers',
            name="Best Bus Stop",
            marker=go.scattermapbox.Marker(
                size=10,
                color='rgb(0, 255, 0)',
            ),
            text=best_stops['address'],
        ))

        fig.update_layout(
            title='Employee addresses and bus stops locations',
            autosize=True,
            hovermode='closest',
            showlegend=True,
            mapbox=dict(
                accesstoken=mapbox_access_token,
                bearing=0,
                center=dict(
                    lat=37.77,
                    lon=-122.5
                ),
                pitch=0,
                zoom=10,
                style='light'
            ),
        )

        fig.show()

# %%
clusterer = Clusterer(employee_data, bus_stops_data)

# %% [markdown]
# ### Plotting employee addresses and bus stops

# %%
clusterer.plot_original_data()

# %%
clusterer.plot_map_box_original_data()
# Out:
# <div>                            <div id="8840561d-d2ba-4ca9-807c-8dbe1f8555ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8840561d-d2ba-4ca9-807c-8dbe1f8555ad")) {                    Plotly.newPlot(                        "8840561d-d2ba-4ca9-807c-8dbe1f8555ad",                        [{"hoverinfo":"text","lat":[37.7276421,37.70418,37.76793,37.72966,37.73624,37.70735,37.7793183,37.70679,37.77934,37.73345,37.76849,37.76582,37.70382,37.73708,37.72134,37.7061,37.71931,37.79508,37.71611,37.71038,37.78338,37.7714,37.7268535,37.73512,37.73829,37.7033115,37.74268,37.79635,37.71694,37.77102,37.71466,37.71974,37.76383,37.7262,37.71396,37.79587,37.729,37.73551,37.7059328,37.7949744,37.7664812,37.74469,37.72597,37.73444,37.72535,37.74594,37.71448,37.71513,37.70586,37.73572,37.76649,37.72061,37.75903,37.73776,37.70615,37.74926,37.71286,37.734821,37.73508,37.71057,37.79451,37.77,37.7274,37.76582,37.78352,37.70512,37.73218,37.73754,37.71394,37.7668,37.74402,37.74457,37.76974,37.73244,37.73612,37.71076,37.7777381,37.78542,37.70488,37.70398,37.79464,37.73299,37.7287906,37.76648,37.71344,37.76798,37.7659734,37.78688,37.714229,37.79686,37.7313779,37.72842,37.71283,37.7703573,37.76623,37.76918,37.71569,37.7329,37.72533,37.71403,37.73282,37.73178,37.78911,37.7127309,37.79272,37.7693349,37.76582,37.73717,37.72727,37.74926,37.76688,37.7673353,37.72902,37.73595,37.74268,37.7346617,37.71106,37.71831,37.70665,37.77016,37.72087,37.72766,37.74926,37.76849,37.71495,37.76675,37.7652109,37.73493,37.73489,37.72468,37.7336749,37.71321,37.71232,37.73726,37.71141,37.74551,37.7339,37.79024,37.74589,37.76974,37.7159,37.71113,37.72131,37.77228,37.71154,37.77049,37.79837,37.72743,37.70333,37.73733,37.79493,37.73572,37.73394,37.79775,37.78104,37.72796,37.7696231,37.7694049,37.7341,37.72064,37.7031766,37.76767,37.76445,37.71629,37.72694,37.76624,37.715296,37.791,37.74536,37.76849,37.7343588,37.72618,37.76794,37.7703573,37.70562,37.76671,37.74508,37.73367,37.7368,37.75903,37.71421,37.7683815,37.71141,37.7680248,37.71533,37.73589,37.7363622,37.7658731,37.76989,37.73568,37.7114,37.74536,37.72444,37.7332211,37.7944,37.71735,37.74926,37.7798599,37.72013,37.7319,37.73609,37.72577,37.73488,37.71382,37.73803,37.7319,37.72586,37.73879,37.73514,37.7655151,37.73759,37.71734,37.74503,37.73645,37.7902,37.73556,37.76904,37.74733,37.73698,37.71472,37.73254,37.7883251,37.7655151,37.71886,37.7961,37.70501,37.77672,37.71376,37.77729,37.73876,37.71131,37.72874,37.7707206,37.74518,37.73343,37.76732,37.7351,37.71916,37.74926,37.76691,37.74519,37.714229,37.73413,37.70542,37.7059328,37.74403,37.7268535,37.74687,37.77069,37.73377,37.73685,37.7668,37.76492,37.7667953,37.73257,37.71203,37.79031,37.7667953,37.76904,37.77193,37.79518,37.73561,37.771,37.76688,37.77708,37.79019,37.72509,37.73311,37.7165721,37.76948,37.7693349,37.74749,37.76597,37.73597,37.72897,37.77121,37.79412,37.71318,37.70613,37.73053,37.7033115,37.72706,37.7329253,37.76793,37.7041,37.7680252,37.72451,37.71951,37.71352,37.72457,37.7262012,37.76864,37.77007,37.7262,37.71581,37.76329,37.75337,37.77045,37.76624,37.71096,37.76812,37.72872,37.72694,37.72691,37.71376,37.77803,37.72707,37.7201785,37.7091,37.71086,37.74419,37.71338,37.76878,37.74519,37.79632,37.7085386,37.7333628,37.79744,37.7207941,37.72861,37.73655,37.71943,37.75337,37.73594,37.78907,37.72573,37.78953,37.715296,37.7638016,37.76874,37.71699,37.77197,37.79017,37.71948,37.73283,37.74657,37.71385,37.72627,37.76582,37.7692,37.76767,37.74704,37.71826,37.715,37.71247,37.73602,37.73731,37.71665,37.7339094,37.74331,37.78979,37.70986,37.76908,37.71535,37.76675,37.7949,37.73176,37.76902,37.71745,37.78764,37.7048865,37.71218,37.79588,37.70497,37.76785,37.76475,37.76708,37.79122,37.7058,37.7303968,37.7650496,37.70529,37.76998,37.73653,37 ...

# %% [markdown]
# ### Apply kmean clustering

# %%
km_labels, km_centers, km_score = clusterer.apply_kmeans_clustering(n_clusters=10)

km_centers_df = pd.DataFrame(km_centers)
km_centers_df.columns = employee_data_location.columns

print("KMeans score: ", km_score)
# Out:
# KMeans score:  0.5777098016971755

# %%
clusterer.plot_clusters(labels=km_labels, centers=km_centers_df)

# %%
clusterer.plot_map_box_clusters(labels=km_labels, centers=km_centers_df)
# Out:
# <div>                            <div id="923a4c60-93bd-4e44-a09c-1980f3f61ffc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("923a4c60-93bd-4e44-a09c-1980f3f61ffc")) {                    Plotly.newPlot(                        "923a4c60-93bd-4e44-a09c-1980f3f61ffc",                        [{"hoverinfo":"text","lat":[37.7276421,37.70418,37.76793,37.72966,37.73624,37.70735,37.7793183,37.70679,37.77934,37.73345,37.76849,37.76582,37.70382,37.73708,37.72134,37.7061,37.71931,37.79508,37.71611,37.71038,37.78338,37.7714,37.7268535,37.73512,37.73829,37.7033115,37.74268,37.79635,37.71694,37.77102,37.71466,37.71974,37.76383,37.7262,37.71396,37.79587,37.729,37.73551,37.7059328,37.7949744,37.7664812,37.74469,37.72597,37.73444,37.72535,37.74594,37.71448,37.71513,37.70586,37.73572,37.76649,37.72061,37.75903,37.73776,37.70615,37.74926,37.71286,37.734821,37.73508,37.71057,37.79451,37.77,37.7274,37.76582,37.78352,37.70512,37.73218,37.73754,37.71394,37.7668,37.74402,37.74457,37.76974,37.73244,37.73612,37.71076,37.7777381,37.78542,37.70488,37.70398,37.79464,37.73299,37.7287906,37.76648,37.71344,37.76798,37.7659734,37.78688,37.714229,37.79686,37.7313779,37.72842,37.71283,37.7703573,37.76623,37.76918,37.71569,37.7329,37.72533,37.71403,37.73282,37.73178,37.78911,37.7127309,37.79272,37.7693349,37.76582,37.73717,37.72727,37.74926,37.76688,37.7673353,37.72902,37.73595,37.74268,37.7346617,37.71106,37.71831,37.70665,37.77016,37.72087,37.72766,37.74926,37.76849,37.71495,37.76675,37.7652109,37.73493,37.73489,37.72468,37.7336749,37.71321,37.71232,37.73726,37.71141,37.74551,37.7339,37.79024,37.74589,37.76974,37.7159,37.71113,37.72131,37.77228,37.71154,37.77049,37.79837,37.72743,37.70333,37.73733,37.79493,37.73572,37.73394,37.79775,37.78104,37.72796,37.7696231,37.7694049,37.7341,37.72064,37.7031766,37.76767,37.76445,37.71629,37.72694,37.76624,37.715296,37.791,37.74536,37.76849,37.7343588,37.72618,37.76794,37.7703573,37.70562,37.76671,37.74508,37.73367,37.7368,37.75903,37.71421,37.7683815,37.71141,37.7680248,37.71533,37.73589,37.7363622,37.7658731,37.76989,37.73568,37.7114,37.74536,37.72444,37.7332211,37.7944,37.71735,37.74926,37.7798599,37.72013,37.7319,37.73609,37.72577,37.73488,37.71382,37.73803,37.7319,37.72586,37.73879,37.73514,37.7655151,37.73759,37.71734,37.74503,37.73645,37.7902,37.73556,37.76904,37.74733,37.73698,37.71472,37.73254,37.7883251,37.7655151,37.71886,37.7961,37.70501,37.77672,37.71376,37.77729,37.73876,37.71131,37.72874,37.7707206,37.74518,37.73343,37.76732,37.7351,37.71916,37.74926,37.76691,37.74519,37.714229,37.73413,37.70542,37.7059328,37.74403,37.7268535,37.74687,37.77069,37.73377,37.73685,37.7668,37.76492,37.7667953,37.73257,37.71203,37.79031,37.7667953,37.76904,37.77193,37.79518,37.73561,37.771,37.76688,37.77708,37.79019,37.72509,37.73311,37.7165721,37.76948,37.7693349,37.74749,37.76597,37.73597,37.72897,37.77121,37.79412,37.71318,37.70613,37.73053,37.7033115,37.72706,37.7329253,37.76793,37.7041,37.7680252,37.72451,37.71951,37.71352,37.72457,37.7262012,37.76864,37.77007,37.7262,37.71581,37.76329,37.75337,37.77045,37.76624,37.71096,37.76812,37.72872,37.72694,37.72691,37.71376,37.77803,37.72707,37.7201785,37.7091,37.71086,37.74419,37.71338,37.76878,37.74519,37.79632,37.7085386,37.7333628,37.79744,37.7207941,37.72861,37.73655,37.71943,37.75337,37.73594,37.78907,37.72573,37.78953,37.715296,37.7638016,37.76874,37.71699,37.77197,37.79017,37.71948,37.73283,37.74657,37.71385,37.72627,37.76582,37.7692,37.76767,37.74704,37.71826,37.715,37.71247,37.73602,37.73731,37.71665,37.7339094,37.74331,37.78979,37.70986,37.76908,37.71535,37.76675,37.7949,37.73176,37.76902,37.71745,37.78764,37.7048865,37.71218,37.79588,37.70497,37.76785,37.76475,37.76708,37.79122,37.7058,37.7303968,37.7650496,37.70529,37.76998,37.73653,37 ...

# %% [markdown]
# ### Apply hierarical clustering

# %%
complete_labels, complete_centers, complete_score = clusterer.apply_hclustering(n_clusters=10, linkage='complete', affinity='manhattan')
average_labels, average_centers, average_score = clusterer.apply_hclustering(n_clusters=10, linkage='average', affinity='manhattan')
ward_labels, ward_centers, ward_score = clusterer.apply_hclustering(n_clusters=10, linkage='ward', affinity='euclidean')

print("Score of Hierarical clustering methods: \n Complete Linkage: {},\n Average Linking: {},\n Ward Linking: {}\n".format(complete_score, average_score, ward_score))
# Out:
# Score of Hierarical clustering methods:
#  Complete Linkage: 0.5547736693973802,
#  Average Linking: 0.5776638750093852,
#  Ward Linking: 0.5494260240570051

# %%
complete_centers_df = pd.DataFrame(complete_centers)
complete_centers_df.columns = employee_data_location.columns

average_centers_df = pd.DataFrame(average_centers)
average_centers_df.columns = employee_data_location.columns

ward_centers_df = pd.DataFrame(ward_centers)
ward_centers_df.columns = employee_data_location.columns

# %%
clusterer.plot_clusters(labels=complete_labels, centers=average_centers_df)

# %%
clusterer.plot_clusters(labels=average_labels, centers=average_centers_df)

# %%
clusterer.plot_clusters(labels=ward_labels, centers=ward_centers_df)

# %%
clusterer.plot_map_box_clusters(labels=average_labels, centers=average_centers_df)
# Out:
# <div>                            <div id="0f0d6d72-2f8f-4581-8a64-734adfb5741a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f0d6d72-2f8f-4581-8a64-734adfb5741a")) {                    Plotly.newPlot(                        "0f0d6d72-2f8f-4581-8a64-734adfb5741a",                        [{"hoverinfo":"text","lat":[37.7276421,37.70418,37.76793,37.72966,37.73624,37.70735,37.7793183,37.70679,37.77934,37.73345,37.76849,37.76582,37.70382,37.73708,37.72134,37.7061,37.71931,37.79508,37.71611,37.71038,37.78338,37.7714,37.7268535,37.73512,37.73829,37.7033115,37.74268,37.79635,37.71694,37.77102,37.71466,37.71974,37.76383,37.7262,37.71396,37.79587,37.729,37.73551,37.7059328,37.7949744,37.7664812,37.74469,37.72597,37.73444,37.72535,37.74594,37.71448,37.71513,37.70586,37.73572,37.76649,37.72061,37.75903,37.73776,37.70615,37.74926,37.71286,37.734821,37.73508,37.71057,37.79451,37.77,37.7274,37.76582,37.78352,37.70512,37.73218,37.73754,37.71394,37.7668,37.74402,37.74457,37.76974,37.73244,37.73612,37.71076,37.7777381,37.78542,37.70488,37.70398,37.79464,37.73299,37.7287906,37.76648,37.71344,37.76798,37.7659734,37.78688,37.714229,37.79686,37.7313779,37.72842,37.71283,37.7703573,37.76623,37.76918,37.71569,37.7329,37.72533,37.71403,37.73282,37.73178,37.78911,37.7127309,37.79272,37.7693349,37.76582,37.73717,37.72727,37.74926,37.76688,37.7673353,37.72902,37.73595,37.74268,37.7346617,37.71106,37.71831,37.70665,37.77016,37.72087,37.72766,37.74926,37.76849,37.71495,37.76675,37.7652109,37.73493,37.73489,37.72468,37.7336749,37.71321,37.71232,37.73726,37.71141,37.74551,37.7339,37.79024,37.74589,37.76974,37.7159,37.71113,37.72131,37.77228,37.71154,37.77049,37.79837,37.72743,37.70333,37.73733,37.79493,37.73572,37.73394,37.79775,37.78104,37.72796,37.7696231,37.7694049,37.7341,37.72064,37.7031766,37.76767,37.76445,37.71629,37.72694,37.76624,37.715296,37.791,37.74536,37.76849,37.7343588,37.72618,37.76794,37.7703573,37.70562,37.76671,37.74508,37.73367,37.7368,37.75903,37.71421,37.7683815,37.71141,37.7680248,37.71533,37.73589,37.7363622,37.7658731,37.76989,37.73568,37.7114,37.74536,37.72444,37.7332211,37.7944,37.71735,37.74926,37.7798599,37.72013,37.7319,37.73609,37.72577,37.73488,37.71382,37.73803,37.7319,37.72586,37.73879,37.73514,37.7655151,37.73759,37.71734,37.74503,37.73645,37.7902,37.73556,37.76904,37.74733,37.73698,37.71472,37.73254,37.7883251,37.7655151,37.71886,37.7961,37.70501,37.77672,37.71376,37.77729,37.73876,37.71131,37.72874,37.7707206,37.74518,37.73343,37.76732,37.7351,37.71916,37.74926,37.76691,37.74519,37.714229,37.73413,37.70542,37.7059328,37.74403,37.7268535,37.74687,37.77069,37.73377,37.73685,37.7668,37.76492,37.7667953,37.73257,37.71203,37.79031,37.7667953,37.76904,37.77193,37.79518,37.73561,37.771,37.76688,37.77708,37.79019,37.72509,37.73311,37.7165721,37.76948,37.7693349,37.74749,37.76597,37.73597,37.72897,37.77121,37.79412,37.71318,37.70613,37.73053,37.7033115,37.72706,37.7329253,37.76793,37.7041,37.7680252,37.72451,37.71951,37.71352,37.72457,37.7262012,37.76864,37.77007,37.7262,37.71581,37.76329,37.75337,37.77045,37.76624,37.71096,37.76812,37.72872,37.72694,37.72691,37.71376,37.77803,37.72707,37.7201785,37.7091,37.71086,37.74419,37.71338,37.76878,37.74519,37.79632,37.7085386,37.7333628,37.79744,37.7207941,37.72861,37.73655,37.71943,37.75337,37.73594,37.78907,37.72573,37.78953,37.715296,37.7638016,37.76874,37.71699,37.77197,37.79017,37.71948,37.73283,37.74657,37.71385,37.72627,37.76582,37.7692,37.76767,37.74704,37.71826,37.715,37.71247,37.73602,37.73731,37.71665,37.7339094,37.74331,37.78979,37.70986,37.76908,37.71535,37.76675,37.7949,37.73176,37.76902,37.71745,37.78764,37.7048865,37.71218,37.79588,37.70497,37.76785,37.76475,37.76708,37.79122,37.7058,37.7303968,37.7650496,37.70529,37.76998,37.73653,37 ...

# %% [markdown]
# We see that the average linking method has the maximum score and make elegant and interesting clusters

# %% [markdown]
# ### Apply Gaussian Mixture Model

# %%
gmm_labels, gmm_centers, gmm_score = clusterer.apply_gmm(n_clusters=10)

# %%
gmm_centers_df = pd.DataFrame(gmm_centers)
gmm_centers_df.columns = employee_data_location.columns

# %%
clusterer.plot_clusters(labels=gmm_labels, centers=gmm_centers_df)

# %%
clusterer.plot_map_box_clusters(labels=gmm_labels, centers=gmm_centers_df)
# Out:
# <div>                            <div id="425dcf7b-df8b-4175-ab2b-599af8469dd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("425dcf7b-df8b-4175-ab2b-599af8469dd7")) {                    Plotly.newPlot(                        "425dcf7b-df8b-4175-ab2b-599af8469dd7",                        [{"hoverinfo":"text","lat":[37.7276421,37.70418,37.76793,37.72966,37.73624,37.70735,37.7793183,37.70679,37.77934,37.73345,37.76849,37.76582,37.70382,37.73708,37.72134,37.7061,37.71931,37.79508,37.71611,37.71038,37.78338,37.7714,37.7268535,37.73512,37.73829,37.7033115,37.74268,37.79635,37.71694,37.77102,37.71466,37.71974,37.76383,37.7262,37.71396,37.79587,37.729,37.73551,37.7059328,37.7949744,37.7664812,37.74469,37.72597,37.73444,37.72535,37.74594,37.71448,37.71513,37.70586,37.73572,37.76649,37.72061,37.75903,37.73776,37.70615,37.74926,37.71286,37.734821,37.73508,37.71057,37.79451,37.77,37.7274,37.76582,37.78352,37.70512,37.73218,37.73754,37.71394,37.7668,37.74402,37.74457,37.76974,37.73244,37.73612,37.71076,37.7777381,37.78542,37.70488,37.70398,37.79464,37.73299,37.7287906,37.76648,37.71344,37.76798,37.7659734,37.78688,37.714229,37.79686,37.7313779,37.72842,37.71283,37.7703573,37.76623,37.76918,37.71569,37.7329,37.72533,37.71403,37.73282,37.73178,37.78911,37.7127309,37.79272,37.7693349,37.76582,37.73717,37.72727,37.74926,37.76688,37.7673353,37.72902,37.73595,37.74268,37.7346617,37.71106,37.71831,37.70665,37.77016,37.72087,37.72766,37.74926,37.76849,37.71495,37.76675,37.7652109,37.73493,37.73489,37.72468,37.7336749,37.71321,37.71232,37.73726,37.71141,37.74551,37.7339,37.79024,37.74589,37.76974,37.7159,37.71113,37.72131,37.77228,37.71154,37.77049,37.79837,37.72743,37.70333,37.73733,37.79493,37.73572,37.73394,37.79775,37.78104,37.72796,37.7696231,37.7694049,37.7341,37.72064,37.7031766,37.76767,37.76445,37.71629,37.72694,37.76624,37.715296,37.791,37.74536,37.76849,37.7343588,37.72618,37.76794,37.7703573,37.70562,37.76671,37.74508,37.73367,37.7368,37.75903,37.71421,37.7683815,37.71141,37.7680248,37.71533,37.73589,37.7363622,37.7658731,37.76989,37.73568,37.7114,37.74536,37.72444,37.7332211,37.7944,37.71735,37.74926,37.7798599,37.72013,37.7319,37.73609,37.72577,37.73488,37.71382,37.73803,37.7319,37.72586,37.73879,37.73514,37.7655151,37.73759,37.71734,37.74503,37.73645,37.7902,37.73556,37.76904,37.74733,37.73698,37.71472,37.73254,37.7883251,37.7655151,37.71886,37.7961,37.70501,37.77672,37.71376,37.77729,37.73876,37.71131,37.72874,37.7707206,37.74518,37.73343,37.76732,37.7351,37.71916,37.74926,37.76691,37.74519,37.714229,37.73413,37.70542,37.7059328,37.74403,37.7268535,37.74687,37.77069,37.73377,37.73685,37.7668,37.76492,37.7667953,37.73257,37.71203,37.79031,37.7667953,37.76904,37.77193,37.79518,37.73561,37.771,37.76688,37.77708,37.79019,37.72509,37.73311,37.7165721,37.76948,37.7693349,37.74749,37.76597,37.73597,37.72897,37.77121,37.79412,37.71318,37.70613,37.73053,37.7033115,37.72706,37.7329253,37.76793,37.7041,37.7680252,37.72451,37.71951,37.71352,37.72457,37.7262012,37.76864,37.77007,37.7262,37.71581,37.76329,37.75337,37.77045,37.76624,37.71096,37.76812,37.72872,37.72694,37.72691,37.71376,37.77803,37.72707,37.7201785,37.7091,37.71086,37.74419,37.71338,37.76878,37.74519,37.79632,37.7085386,37.7333628,37.79744,37.7207941,37.72861,37.73655,37.71943,37.75337,37.73594,37.78907,37.72573,37.78953,37.715296,37.7638016,37.76874,37.71699,37.77197,37.79017,37.71948,37.73283,37.74657,37.71385,37.72627,37.76582,37.7692,37.76767,37.74704,37.71826,37.715,37.71247,37.73602,37.73731,37.71665,37.7339094,37.74331,37.78979,37.70986,37.76908,37.71535,37.76675,37.7949,37.73176,37.76902,37.71745,37.78764,37.7048865,37.71218,37.79588,37.70497,37.76785,37.76475,37.76708,37.79122,37.7058,37.7303968,37.7650496,37.70529,37.76998,37.73653,37 ...

# %%
print("The scores of the algorithms we used: \n \
       KMeans score: {} \n \
       Average hierarical score: {} \n \
       GMM score: {}".format(km_score, average_score, gmm_score))
# Out:
# The scores of the algorithms we used:
#         KMeans score: 0.5777098016971755
#         Average hierarical score: 0.5776638750093852
#         GMM score: 0.5600892455534239

# %%
clusterer.plot_clusters(labels=km_labels, centers=km_centers_df)

clusterer.plot_clusters(labels=average_labels, centers=average_centers_df)

clusterer.plot_clusters(labels=gmm_labels, centers=gmm_centers_df)

# %% [markdown]
# ### Get the best bus stops

# %% [markdown]
# We will use the hierarical clustering algorith with the average linkage to get the best bus stops.
#
# We will use Haversine Distance to calculate the distance between the centroids of the clusters and the bus stops, then we will get the nearest bus stop to each cluster

# %%
def get_best_stops(bus_stops_data, centroids):
    
    bus_stops = bus_stops_data[['latitude', 'longitude']].to_numpy()
    
    # get the arguments of the 10 best bus stops 
    argmin_distances = []

    for centroid in centroids:
        distance_arr = hs.haversine_vector(centroid, bus_stops, comb=True)
        argmin_distances.append(distance_arr.argmin())

    # get the location of each of them 
    best_bus_stops = []
    for argmin_distance in argmin_distances:
        best_bus_stops.append(bus_stops[argmin_distance])

    # get the bus stops  
    best_stops = pd.DataFrame(columns=bus_stops_data.columns)
    for i in range(10):
        data = bus_stops_data[(bus_stops_data['latitude']==best_bus_stops[i][0]) & (bus_stops_data['longitude']==best_bus_stops[i][1])]
        best_stops = pd.concat([best_stops, data])
    
    return best_stops

# %%
best_bus_stops = get_best_stops(bus_stops_data=bus_stops_data, centroids=average_centers)
best_bus_stops
# Out:
#      Street_One    Street_Two                   address  \
# 6    MISSION ST       ERIE ST       MISSION ST, ERIE ST
# 106  MISSION ST   BOSWORTH ST   MISSION ST, BOSWORTH ST
# 54   MISSION ST     LASKIE ST     MISSION ST, LASKIE ST
# 30   MISSION ST  CORTLAND AVE  MISSION ST, CORTLAND AVE
# 0    MISSION ST     ITALY AVE     MISSION ST, ITALY AVE
# 73   MISSION ST      SHAW ALY      MISSION ST, SHAW ALY
# 88   MISSION ST      ROLPH ST      MISSION ST, ROLPH ST
# 17   MISSION ST   TRUMBULL ST   MISSION ST, TRUMBULL ST
# 23   MISSION ST     OLIVER ST     MISSION ST, OLIVER ST
# 55   MISSION ST       29TH ST       MISSION ST, 29TH ST
#
#                                               response  latitude  longitude
# 6    {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.76927 -122.41673
# 106  {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.73428 -122.43791
# 54   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.77701 -122.41449
# 30   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.73897 -122.41546
# 0    {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.71675 -122.43594
# 73   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.78877  -122.3983
# 88   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.71261 -122.43459
# 17   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.73092 -122.42544
# 23   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.70894 -122.45019
# 55   {'Response': {'MetaInfo': {'Timestamp': '2022-...  37.74399 -122.42183

# %%
clusterer.plot_best_stops(labels=average_labels, centers=average_centers_df, best_stops=best_bus_stops)

# %%
clusterer.plot_map_box_best_stops(labels=average_labels, centers=average_centers_df, best_stops=best_bus_stops)
# Out:
# <div>                            <div id="171ae00e-ab5a-47c1-ac82-e97b1cef5f73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("171ae00e-ab5a-47c1-ac82-e97b1cef5f73")) {                    Plotly.newPlot(                        "171ae00e-ab5a-47c1-ac82-e97b1cef5f73",                        [{"hoverinfo":"text","lat":[37.7276421,37.70418,37.76793,37.72966,37.73624,37.70735,37.7793183,37.70679,37.77934,37.73345,37.76849,37.76582,37.70382,37.73708,37.72134,37.7061,37.71931,37.79508,37.71611,37.71038,37.78338,37.7714,37.7268535,37.73512,37.73829,37.7033115,37.74268,37.79635,37.71694,37.77102,37.71466,37.71974,37.76383,37.7262,37.71396,37.79587,37.729,37.73551,37.7059328,37.7949744,37.7664812,37.74469,37.72597,37.73444,37.72535,37.74594,37.71448,37.71513,37.70586,37.73572,37.76649,37.72061,37.75903,37.73776,37.70615,37.74926,37.71286,37.734821,37.73508,37.71057,37.79451,37.77,37.7274,37.76582,37.78352,37.70512,37.73218,37.73754,37.71394,37.7668,37.74402,37.74457,37.76974,37.73244,37.73612,37.71076,37.7777381,37.78542,37.70488,37.70398,37.79464,37.73299,37.7287906,37.76648,37.71344,37.76798,37.7659734,37.78688,37.714229,37.79686,37.7313779,37.72842,37.71283,37.7703573,37.76623,37.76918,37.71569,37.7329,37.72533,37.71403,37.73282,37.73178,37.78911,37.7127309,37.79272,37.7693349,37.76582,37.73717,37.72727,37.74926,37.76688,37.7673353,37.72902,37.73595,37.74268,37.7346617,37.71106,37.71831,37.70665,37.77016,37.72087,37.72766,37.74926,37.76849,37.71495,37.76675,37.7652109,37.73493,37.73489,37.72468,37.7336749,37.71321,37.71232,37.73726,37.71141,37.74551,37.7339,37.79024,37.74589,37.76974,37.7159,37.71113,37.72131,37.77228,37.71154,37.77049,37.79837,37.72743,37.70333,37.73733,37.79493,37.73572,37.73394,37.79775,37.78104,37.72796,37.7696231,37.7694049,37.7341,37.72064,37.7031766,37.76767,37.76445,37.71629,37.72694,37.76624,37.715296,37.791,37.74536,37.76849,37.7343588,37.72618,37.76794,37.7703573,37.70562,37.76671,37.74508,37.73367,37.7368,37.75903,37.71421,37.7683815,37.71141,37.7680248,37.71533,37.73589,37.7363622,37.7658731,37.76989,37.73568,37.7114,37.74536,37.72444,37.7332211,37.7944,37.71735,37.74926,37.7798599,37.72013,37.7319,37.73609,37.72577,37.73488,37.71382,37.73803,37.7319,37.72586,37.73879,37.73514,37.7655151,37.73759,37.71734,37.74503,37.73645,37.7902,37.73556,37.76904,37.74733,37.73698,37.71472,37.73254,37.7883251,37.7655151,37.71886,37.7961,37.70501,37.77672,37.71376,37.77729,37.73876,37.71131,37.72874,37.7707206,37.74518,37.73343,37.76732,37.7351,37.71916,37.74926,37.76691,37.74519,37.714229,37.73413,37.70542,37.7059328,37.74403,37.7268535,37.74687,37.77069,37.73377,37.73685,37.7668,37.76492,37.7667953,37.73257,37.71203,37.79031,37.7667953,37.76904,37.77193,37.79518,37.73561,37.771,37.76688,37.77708,37.79019,37.72509,37.73311,37.7165721,37.76948,37.7693349,37.74749,37.76597,37.73597,37.72897,37.77121,37.79412,37.71318,37.70613,37.73053,37.7033115,37.72706,37.7329253,37.76793,37.7041,37.7680252,37.72451,37.71951,37.71352,37.72457,37.7262012,37.76864,37.77007,37.7262,37.71581,37.76329,37.75337,37.77045,37.76624,37.71096,37.76812,37.72872,37.72694,37.72691,37.71376,37.77803,37.72707,37.7201785,37.7091,37.71086,37.74419,37.71338,37.76878,37.74519,37.79632,37.7085386,37.7333628,37.79744,37.7207941,37.72861,37.73655,37.71943,37.75337,37.73594,37.78907,37.72573,37.78953,37.715296,37.7638016,37.76874,37.71699,37.77197,37.79017,37.71948,37.73283,37.74657,37.71385,37.72627,37.76582,37.7692,37.76767,37.74704,37.71826,37.715,37.71247,37.73602,37.73731,37.71665,37.7339094,37.74331,37.78979,37.70986,37.76908,37.71535,37.76675,37.7949,37.73176,37.76902,37.71745,37.78764,37.7048865,37.71218,37.79588,37.70497,37.76785,37.76475,37.76708,37.79122,37.7058,37.7303968,37.7650496,37.70529,37.76998,37.73653,37 ...
